# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#dependencies
import requests
import json
import gzip
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from numpy import random
from config import api_key
from pprint import pprint
from scipy.stats import linregress
from sklearn import datasets
 #Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Output File (CSV)
output_data_file = "output_data/output_weather_data_file.csv"

# %%
# quick look at data output struture using name = "San Jose" as an example
#url = "http://api.openweathermap.org/data/2.5/weather?"
#test_city = "San Jose"
#units = "imperial"
# Build query URL
#test_query_url = url + units + "&appid=" + api_key +"&q="+ test_city
#test_query_url

# %%
#Test url and Get weather data for "San Jose"
#test_response = requests.get(test_query_url).json()
#test_response

# get country name
#countryy = test_response['sys']['country']
#countryy
#idd= test_response['sys']['id']
#idd
#temp= test_response['main']['temp']
#temp

# %% [markdown]
# ## Generate Cities List

# %%
city_from_citypy = []

max_city = 1500
for i in range(max_city):
    long=random.uniform(180,-180)
    lat =random.uniform(90,-90)
    city=citipy.nearest_city(lat,long)
    city_name=city.city_name
    if city_name not in city_from_citypy:
        city_from_citypy.append(city_name)
print (len(city_from_citypy))
# Out:
# 617

# %%
type(city_from_citypy)
# Out:
# list

# %%
# convert list to dataframe
citypy_df = DataFrame(city_from_citypy,columns=['CityPy'])

citypy_df['CityPy'] = citypy_df['CityPy'].str.title()
citypy_df
# Out:
#              CityPy
# 0       Yellowknife
# 1    Cabo San Lucas
# 2           Ushuaia
# 3              Hilo
# 4             Marti
# ..              ...
# 612          Galich
# 613           Manga
# 614       Pringsewu
# 615          Darhan
# 616         Kamenka
#
# [617 rows x 1 columns]

# %%
type(citypy_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
city = citypy_df['CityPy']
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
city
# Out:
# 0         Yellowknife
# 1      Cabo San Lucas
# 2             Ushuaia
# 3                Hilo
# 4               Marti
#             ...
# 612            Galich
# 613             Manga
# 614         Pringsewu
# 615            Darhan
# 616           Kamenka
# Name: CityPy, Length: 617, dtype: object

# %%
random_search_data = []
city_list = []
country_list = []


searchCnt = 0
print("Begin API Call to OpenWeather Database ")
print("---------------------------------------")

#Loop thry each city
for city in citypy_df["CityPy"]:
    try:
        # Create search query, make request and store in json
        print(f"Processing record {searchCnt} for the city: {city}")
        searchCnt += 1
        
        weather_response = requests.get(query_url + city).json()     
        
        # Try to grab the country and id of cities if they are available in openweather API
        country_data      = weather_response['sys']['country']
        city_id          = weather_response['id']
        temp = weather_response['main']['temp']
        
        random_search_data.append(weather_response)
        city_list.append(city)
        country_list.append(country_data)
        print(f"Record found for city id: {city_id} with city name : {city}")
       
   
    # Handle exceptions for a city that is not available in the openweather API
    except:
        #append null value
        print(f"No weather record found for city: {city}")
        pass


    
print("---------------------------------------")
print("Processing Complete")
# Out:
# Begin API Call to OpenWeather Database
# ---------------------------------------
# Processing record 0 for the city: Yellowknife
# Record found for city id: 6185377 with city name : Yellowknife
# Processing record 1 for the city: Cabo San Lucas
# Record found for city id: 3985710 with city name : Cabo San Lucas
# Processing record 2 for the city: Ushuaia
# Record found for city id: 3833367 with city name : Ushuaia
# Processing record 3 for the city: Hilo
# Record found for city id: 5855927 with city name : Hilo
# Processing record 4 for the city: Marti
# Record found for city id: 3547519 with city name : Marti
# Processing record 5 for the city: Rikitea
# Record found for city id: 4030556 with city name : Rikitea
# Processing record 6 for the city: Lebu
# Record found for city id: 3883457 with city name : Lebu
# Processing record 7 for the city: Codrington
# Record found for city id: 2171099 with city name : Codrington
# Processing record 8 for the city: Ahipara
# Record found for city id: 2194098 with city name : Ahipara
# Processing record 9 for the city: Santa Maria
# Record found for city id: 3450083 with city name : Santa Maria
# Processing record 10 for the city: Kapaa
# Record found for city id: 5848280 with city name : Kapaa
# Processing record 11 for the city: Aleksandrovka
# Record found for city id: 713676 with city name : Aleksandrovka
# Processing record 12 for the city: Ilo
# Record found for city id: 3938415 with city name : Ilo
# Processing record 13 for the city: Port Lincoln
# Record found for city id: 2063036 with city name : Port Lincoln
# Processing record 14 for the city: Pocoes
# Record found for city id: 3453337 with city name : Pocoes
# Processing record 15 for the city: Carnarvon
# Record found for city id: 2074865 with city name : Carnarvon
# Processing record 16 for the city: Punta Arenas
# Record found for city id: 3874787 with city name : Punta Arenas
# Processing record 17 for the city: Bluff
# Record found for city id: 2206939 with city name : Bluff
# Processing record 18 for the city: Vardo
# Record found for city id: 777019 with city name : Vardo
# Processing record 19 for the city: Yumen
# Record found for city id: 1528998 with city name : Yumen
# Processing record 20 for the city: Chumikan
# Record found for city id: 2025256 with city name : Chumikan
# Processing record 21 for the city: Fort Abbas
# Record found for city id: 1179223 with city name : Fort Abbas
# Processing record 22 for the city: Barawe
# No weather record found for city: Barawe
# Processing record 23 for the city: Nizhnevartovsk
# Record found for city id: 1497543 with city name : Nizhnevartovsk
# Processing record 24 for the city: Ngukurr
# No weather record found for city: Ngukurr
# Processing record 25 for the city: Pacific Grove
# Record found for city id: 5380437 with city name : Pacific Grove
# Processing record 26 for the city: Pangnirtung
# Record found for city id: 6096551 with city name : Pangnirtung
# Processing record 27 for the city: Atuona
# Record found for city id: 4020109 with city name : Atuona
# Processing record 28 for the city: Puerto Ayora
# Record found for city id: 3652764 with city name : Puerto Ayora
# Processing record 29 for the city: Constantine
# Record found for city id: 2501152 with city name : Constantine
# Processing record 30 for the city: Port Alfred
# Record found for city id: 964432 with city name : Port Alfred
# Processing record 31 for the city: Bathsheba
# Record found for city id: 3374083 with city name : Bathsheba
# Processing record 32 for the city: Hovd
# Record found for city id: 1516048 with city name : Hovd
# Processing record 33 for the city: Yangjiang
# Record found for city id: 1806408 with city name : Yangjiang
# Processing record 34 for the city: Leningradskiy
# Record found for city id: 2123814 with city name : Leningradskiy
# Processing record 35 for the city: Torbay
# Record found for city id: 6167817 with city name : Torbay
# Processing record 36 for the city: Cape Town
# Record found for city id: 3369157 with city name : Cape Town
# Processing record 37 for the city: Galesong
# Record found for city id: 1644605 with city name : Galesong
# Processing record 38 for the city: Mhlume
# Record found for city id: 934966 with city name : Mhlume
# Processing record 39 for the city: Ust-Uda
# Record found for city id: 2013865 with city name : Ust-Uda
# Processing record 40 for the city: Qaanaaq
# Record found for city id: 3831208 with city name : Qaanaaq
# Processing record 41 for the city: Belushya Guba
# No weather record found for city: Belushya Guba
# Processing record 42 for the city: Lagoa
# Record found for city id: 3372964 with city name : Lagoa
# Processing record 43 for the city: Los Llanos De Aridane
# Record found for city id: 2514651 with city name : Los Llanos De Aridane
# Processing record 44 for the city: Pevek
# Record found for city id: 2122090 with city name : Pevek
# Processing record 45 for the city: Puebloviejo
# Record found for city id: 3671615 with city name : Puebloviejo
# Processing record 46 for the city: Tabiauea
# No weather record found for city: Tabiauea
# Processing record 47 for the city: Sorland
# Record found for city id: 3137469 with city name : Sorland
# Processing record 48 for the city: Ostrovnoy
# Record found for city id: 556268 with city name : Ostrovnoy
# Processing record 49 for the city: Ejido
# Record found for city id: 3644417 with city name : Ejido
# Processing record 50 for the city: Hobart
# Record found for city id: 2163355 with city name : Hobart
# Processing record 51 for the city: Jamestown
# Record found for city id: 5122534 with city name : Jamestown
# Processing record 52 for the city: Poum
# Record found for city id: 2138555 with city name : Poum
# Processing record 53 for the city: Taolanaro
# No weather record found for city: Taolanaro
# Processing record 54 for the city: Komsomolskiy
# Record found for city id: 1513491 with city name : Komsomolskiy
# Processing record 55 for the city: Chokurdakh
# Record found for city id: 2126123 with city name : Chokurdakh
# Processing record 56 for the city: Ixtapa
# Record found for city id: 4004293 with city name : Ixtapa
# Processing record 57 for the city: Mataura
# Record found for city id: 6201424 with city name : Mataura
# Processing record 58 for the city: Meulaboh
# Record found for city id: 1214488 with city name : Meulaboh
# Processing record 59 for the city: Sentyabrskiy
# No weather record found for city: Sentyabrskiy
# Processing record 60 for the city: Mogadishu
# Record found for city id: 53654 with city name : Mogadishu
# Processing record 61 for the city: Barrow
# Record found for city id: 5880054 with city name : Barrow
# Processing record 62 for the city: Jedburgh
# Record found for city id: 2645970 with city name : Jedburgh
# Processing record 63 for the city: Slevik
# No weather record found for city: Slevik
# Processing record 64 for the city: Fortuna
# Record found for city id: 5563839 with city name : Fortuna
# Processing record 65 for the city: Vinh Long
# Record found for city id: 1562693 with city name : Vinh Long
# Processing record 66 for the city: Florianopolis
# Record found for city id: 6323121 with city name : Florianopolis
# Processing record 67 for the city: Thanh Hoa
# Record found for city id: 1566166 with city name : Thanh Hoa
# Processing record 68 for the city: Burnie
# Record found for city id: 2173125 with city name : Burnie
# Processing record 69 for the city: Kolokani
# Record found for city id: 2454955 with city name : Kolokani
# Processing record 70 for the city: Linguere
# Record found for city id: 2249281 with city name : Linguere
# Processing record 71 for the city: Duz
# No weather record found for city: Duz
# Processing record 72 for the city: Yerbogachen
# Record found for city id: 2012956 with city name : Yerbogachen
# Processing record 73 for the city: Hermanus
# Record found for city id: 3366880 with city name : Hermanus
# Processing record 74 for the city: Lompoc
# Record found for city id: 5367788 with city name : Lompoc
# Processing record 75 for the city: Dikson
# Record found for city id: 1507390 with city name : Dikson
# Processing record 76 for the city: Barentsburg
# No weather record found for city: Barentsburg
# Processing record 77 for the city: Arraial Do Cabo
# Record found for city id: 3471451 with city name : Arraial Do Cabo
# Processing record 78 for the city: Ancud
# Record found for city id: 3899695 with city name : Ancud
# Processing record 79 for the city: Panubigan
# Record found for city id: 1958647 with city name : Panubigan
# Processing record 80 for the city: Westport
# Record found for city id: 4845585 with city name : Westport
# Processing record 81 for the city: Constitucion
# Record found for city id: 3893726 with city name : Constitucion
# Processing record 82 for the city: Kavaratti
# Record found for city id: 1267390 with city name : Kavaratti
# Processing record 83 for the city: Bredasdorp
# Record found for city id: 1015776 with city name : Bredasdorp
# Processing record 84 for the city: Sao Felix Do Xingu
# Record found for city id: 3388847 with city name : Sao Felix Do Xingu
# Processing record 85 for the city: Rafsanjan
# Record found for city id: 118994 with city name : Rafsanjan
# Processing record 86 for the city: Edremit
# Record found for city id: 315985 with city name : Edremit
# Processing record 87 for the city: Salalah
# Record found for city id: 286621 with city name : Salalah
# Processing record 88 for the city: Sistranda
# Record found for city id: 3139597 with city name : Sistranda
# Processing record 89 for the city: Joshimath
# Record found for city id: 1268814 with city name : Joshimath
# Processing record 90 for the city: Fairbanks
# Record found for city id: 5861897 with city name : Fairbanks
# Processing record 91 for the city: Rio Gallegos
# Record found for city id: 3838859 with city name : Rio Gallegos
# Processing record 92 for the city: Tashla
# Record found for city id: 484232 with city name : Tashla
# Processing record 93 for the city: Belaya Gora
# Record found for city id: 2126785 with city name : Belaya Gora
# Processing record 94 for the city: Prince Albert
# Record found for city id: 6113335 with city name : Prince Albert
# Processing record 95 for the city: Bethel
# Record found for city id: 5282297 with city name : Bethel
# Processing record 96 for the city: Bandarbeyla
# Record found for city id: 64814 with city name : Bandarbeyla
# Processing record 97 for the city: Ilhabela
# Record found for city id: 3461425 with city name : Ilhabela
# Processing record 98 for the city: Touros
# Record found for city id: 3386213 with city name : Touros
# Processing record 99 for the city: Sitka
# Record found for city id: 5557293 with city name : Sitka
# Processing record 100 for the city: Hami
# Record found for city id: 1529484 with city name : Hami
# Processing record 101 for the city: Albany
# Record found for city id: 5106841 with city name : Albany
# Processing record 102 for the city: Minudasht
# Record found for city id: 132938 with city name : Minudasht
# Processing record 103 for the city: Segezha
# Record found for city id: 497927 with city name : Segezha
# Processing record 104 for the city: Iqaluit
# Record found for city id: 5983720 with city name : Iqaluit
# Processing record 105 for the city: Butaritari
# Record found for city id: 2110227 with city name : Butaritari
# Processing record 106 for the city: Hithadhoo
# Record found for city id: 1282256 with city name : Hithadhoo
# Processing record 107 for the city: Illoqqortoormiut
# No weather record found for city: Illoqqortoormiut
# Processing record 108 for the city: Hay River
# Record found for city id: 5972762 with city name : Hay River
# Processing record 109 for the city: Busselton
# Record found for city id: 2075265 with city name : Busselton
# Processing record 110 for the city: Albania
# Record found for city id: 783754 with city name : Albania
# Processing record 111 for the city: Mareeba
# Record found for city id: 2158767 with city name : Mareeba
# Processing record 112 for the city: Tiznit
# Record found for city id: 2527087 with city name : Tiznit
# Processing record 113 for the city: Maracaibo
# Record found for city id: 3633009 with city name : Maracaibo
# Processing record 114 for the city: Halifax
# Record found for city id: 6324729 with city name : Halifax
# Processing record 115 for the city: Catamarca
# Record found for city id: 3837702 with city name : Catamarca
# Processing record 116 for the city: Nikolskoye
# Record found for city id: 546105 with city name : Nikolskoye
# Processing record 117 for the city: Albanel
# Record found for city id: 5883074 with city name : Albanel
# Processing record 118 for the city: Zhangye
# Record found for city id: 1785036 with city name : Zhangye
# Processing record 119 for the city: Saskylakh
# Record found for city id: 2017155 with city name : Saskylakh
# Processing record 120 for the city: La Ronge
# Record found for city id: 6050066 with city name : La Ronge
# Processing record 121 for the city: Killarney
# Record found for city id: 2963370 with city name : Killarney
# Processing record 122 for the city: Naze
# Record found for city id: 1855540 with city name : Naze
# Processing record 123 for the city: Hasaki
# Record found for city id: 2112802 with city name : Hasaki
# Processing record 124 for the city: Karabulak
# Record found for city id: 552951 with city name : Karabulak
# Processing record 125 for the city: Nerchinskiy Zavod
# Record found for city id: 2019323 with city name : Nerchinskiy Zavod
# Processing record 126 for the city: Khatanga
# Record found for city id: 2022572 with city name : Khatanga
# Processing record 127 for the city: Vaini
# Record found for city id: 4032243 with city name : Vaini
# Processing record 128 for the city: Meyungs
# No weather record found for city: Meyungs
# Processing record 129 for the city: Samarai
# Record found for city id: 2132606 with city name : Samarai
# Processing record 130 for the city: Honiara
# Record found for city id: 2108502 with city name : Honiara
# Processing record 131 for the city: East London
# Record found for city id: 1006984 with city name : East London
# Processing record 132 for the city: Nha Trang
# Record found for city id: 1572151 with city name : Nha Trang
# Processing record 133 for the city: Grindavik
# Record found for city id: 3416888 with city name : Grindavik
# Processing record 134 for the city: Kahului
# Record found for city id: 5847411 with city name : Kahului
# Processing record 135 for the city: Nobres
# Record found for city id: 3456277 with city name : Nobres
# Processing record 136 for the city: Severo-Kurilsk
# Record found for city id: 2121385 with city name : Severo-Kurilsk
# Processing record 137 for the city: Pangai
# Record found for city id: 4032369 with city name : Pangai
# Processing record 138 for the city: Kohima
# Record found for city id: 1266366 with city name : Kohima
# Processing record 139 for the city: Bonfim
# Record found for city id: 3405215 with city name : Bonfim
# Processing record 140 for the city: Utinga
# Record found for city id: 3392998 with city name : Utinga
# Processing record 141 for the city: Dali
# Record found for city id: 1814093 with city name : Dali
# Processing record 142 for the city: Mao
# Record found for city id: 2514301 with city name : Mao
# Processing record 143 for the city: Shimoda
# Record found for city id: 1852357 with city name : Shimoda
# Processing record 144 for the city: Tucumcari
# Record found for city id: 5495360 with city name : Tucumcari
# Processing record 145 for the city: Wegorzewo
# Record found for city id: 756048 with city name : Wegorzewo
# Processing record 146 for the city: Longyearbyen
# Record found for city id: 2729907 with city name : Longyearbyen
# Processing record 147 for the city: Chuy
# Record found for city id: 3443061 with city name : Chuy
# Processing record 148 for the city: Newport
# Record found for city id: 2641598 with city name : Newport
# Processing record 149 for the city: Ukiah
# Record found for city id: 5404476 with city name : Ukiah
# Processing record 150 for the city: Upernavik
# Record found for city id: 3418910 with city name : Upernavik
# Processing record 151 for the city: Mahabaleshwar
# Record found for city id: 1264491 with city name : Mahabaleshwar
# Processing record 152 for the city: Guerrero Negro
# Record found for city id: 4021858 with city name : Guerrero Negro
# Processing record 153 for the city: Montmagny
# Record found for city id: 2992287 with city name : Montmagny
# Processing record 154 for the city: Airai
# Record found for city id: 1651810 with city name : Airai
# Processing record 155 for the city: Provideniya
# Record found for city id: 4031574 with city name : Provideniya
# Processing record 156 for the city: Makokou
# Record found for city id: 2399371 with city name : Makokou
# Processing record 157 for the city: Mar Del Plata
# Record found for city id: 3430863 with city name : Mar Del Plata
# Processing record 158 for the city: Zeerust
# Record found for city id: 937136 with city name : Zeerust
# Processing record 159 for the city: Savonlinna
# Record found for city id: 637292 with city name : Savonlinna
# Processing record 160 for the city: Ambilobe
# Record found for city id: 1082243 with city name : Ambilobe
# Processing record 161 for the city: Pisco
# Record found for city id: 3932145 with city name : Pisco
# Processing record 162 for the city: Talavera De La Reina
# Record found for city id: 2510693 with city name : Talavera De La Reina
# Processing record 163 for the city: Kemi
# Record found for city id: 653257 with city name : Kemi
# Processing record 164 for the city: Alofi
# Record found for city id: 4036284 with city name : Alofi
# Processing record 165 for the city: Dukat
# Record found for city id: 2125906 with city name : Dukat
# Processing record 166 for the city: Sorong
# Record found for city id: 1626542 with city name : Sorong
# Processing record 167 for the city: Mouzakion
# No weather record found for city: Mouzakion
# Processing record 168 for the city: Concarneau
# Record found for city id: 3024035 with city name : Concarneau
# Processing record 169 for the city: Roebourne
# Record found for city id: 2062276 with city name : Roebourne
# Processing record 170 for the city: Armidale
# Record found for city id: 2177671 with city name : Armidale
# Processing record 171 for the city: Salvacion
# Record found for city id: 1690741 with city name : Salvacion
# Processing record 172 for the city: Nanortalik
# Record found for city id: 3421765 with city name : Nanortalik
# Processing record 173 for the city: Tsihombe
# No weather record found for city: Tsihombe
# Processing record 174 for the city: Kavieng
# Record found for city id: 2094342 with city name : Kavieng
# Processing record 175 for the city: Aklavik
# Record found for city id: 5882953 with city name : Aklavik
# Processing record 176 for the city: Ketchikan
# Record found for city id: 5554428 with city name : Ketchikan
# Processing record 177 for the city: Castro
# Record found for city id: 3466704 with city name : Castro
# Processing record 178 for the city: Souillac
# Record found for city id: 933995 with city name : Souillac
# Processing record 179 for the city: Clyde River
# Record found for city id: 5924351 with city name : Clyde River
# Processing record 180 for the city: San Jose De Buan
# Record found for city id: 1689399 with city name : San Jose De Buan
# Processing record 181 for the city: Saint George
# Record found for city id: 5546220 with city name : Saint George
# Processing record 182 for the city: Moa
# Record found for city id: 3546791 with city name : Moa
# Processing record 183 for the city: Tasiilaq
# Record found for city id: 3424607 with city name : Tasiilaq
# Processing record 184 for the city: Aksarka
# Record found for city id: 1512019 with city name : Aksarka
# Processing record 185 for the city: Kalmunai
# Record found for city id: 1242110 with city name : Kalmunai
# Processing record 186 for the city: Khani
# Record found for city id: 610864 with city name : Khani
# Processing record 187 for the city: Avarua
# Record found for city id: 4035715 with city name : Avarua
# Processing record 188 for the city: Vodnyy
# Record found for city id: 472976 with city name : Vodnyy
# Processing record 189 for the city: Srednekolymsk
# Record found for city id: 2121025 with city name : Srednekolymsk
# Processing record 190 for the city: Saleaula
# No weather record found for city: Saleaula
# Processing record 191 for the city: Banmo
# No weather record found for city: Banmo
# Processing record 192 for the city: Kariba
# Record found for city id: 889215 with city name : Kariba
# Processing record 193 for the city: Nador
# Record found for city id: 2541479 with city name : Nador
# Processing record 194 for the city: Kupang
# Record found for city id: 2057087 with city name : Kupang
# Processing record 195 for the city: Mombaca
# Record found for city id: 3394649 with city name : Mombaca
# Processing record 196 for the city: Saint-Philippe
# Record found for city id: 935215 with city name : Saint-Philippe
# Processing record 197 for the city: Ponta Delgada
# Record found for city id: 3372783 with city name : Ponta Delgada
# Processing record 198 for the city: Neiafu
# Record found for city id: 4032420 with city name : Neiafu
# Processing record 199 for the city: Kemijarvi
# Record found for city id: 653272 with city name : Kemijarvi
# Processing record 200 for the city: Saldanha
# Record found for city id: 3361934 with city name : Saldanha
# Processing record 201 for the city: Norman Wells
# Record found for city id: 6089245 with city name : Norman Wells
# Processing record 202 for the city: Lincoln
# Record found for city id: 5072006 with city name : Lincoln
# Processing record 203 for the city: College
# Record found for city id: 5859699 with city name : College
# Processing record 204 for the city: Nautla
# Record found for city id: 3522788 with city name : Nautla
# Processing record 205 for the city: Baiao
# Record found for city id: 3406844 with city name : Baiao
# Processing record 206 for the city: Georgetown
# Record found for city id: 1735106 with city name : Georgetown
# Processing record 207 for the city: Esperance
# Record found for city id: 2071860 with city name : Esperance
# Processing record 208 for the city: Husavik
# Record found for city id: 2629833 with city name : Husavik
# Processing record 209 for the city: Karpuninskiy
# No weather record found for city: Karpuninskiy
# Processing record 210 for the city: Jalu
# Record found for city id: 86049 with city name : Jalu
# Processing record 211 for the city: Babu
# Record found for city id: 1817858 with city name : Babu
# Processing record 212 for the city: Katsuura
# Record found for city id: 2112309 with city name : Katsuura
# Processing record 213 for the city: Traipu
# Record found for city id: 3386198 with city name : Traipu
# Processing record 214 for the city: Fomboni
# Record found for city id: 921889 with city name : Fomboni
# Processing record 215 for the city: Cherskiy
# Record found for city id: 2126199 with city name : Cherskiy
# Processing record 216 for the city: Muros
# Record found for city id: 3115824 with city name : Muros
# Processing record 217 for the city: Cockburn Town
# Record found for city id: 3576994 with city name : Cockburn Town
# Processing record 218 for the city: Berlevag
# Record found for city id: 780687 with city name : Berlevag
# Processing record 219 for the city: Havelock
# Record found for city id: 4470244 with city name : Havelock
# Processing record 220 for the city: Margate
# Record found for city id: 2643044 with city name : Margate
# Processing record 221 for the city: Hambantota
# Record found for city id: 1244926 with city name : Hambantota
# Processing record 222 for the city: Santa Rosa
# Record found for city id: 1687894 with city name : Santa Rosa
# Processing record 223 for the city: Palabuhanratu
# No weather record found for city: Palabuhanratu
# Processing record 224 for the city: Kampot
# Record found for city id: 1831112 with city name : Kampot
# Processing record 225 for the city: Grand Baie
# Record found for city id: 934482 with city name : Grand Baie
# Processing record 226 for the city: Mizdah
# Record found for city id: 2214827 with city name : Mizdah
# Processing record 227 for the city: Coahuayana
# Record found for city id: 4013679 with city name : Coahuayana
# Processing record 228 for the city: Port Elizabeth
# Record found for city id: 964420 with city name : Port Elizabeth
# Processing record 229 for the city: Kostomuksha
# Record found for city id: 543899 with city name : Kostomuksha
# Processing record 230 for the city: Kodiak
# Record found for city id: 5866583 with city name : Kodiak
# Processing record 231 for the city: Senno
# Record found for city id: 497024 with city name : Senno
# Processing record 232 for the city: Kudahuvadhoo
# Record found for city id: 1337607 with city name : Kudahuvadhoo
# Processing record 233 for the city: Acarau
# Record found for city id: 3408368 with city name : Acarau
# Processing record 234 for the city: Eldikan
# No weather record found for city: Eldikan
# Processing record 235 for the city: Bubaque
# Record found for city id: 2374583 with city name : Bubaque
# Processing record 236 for the city: Springbok
# Record found for city id: 3361142 with city name : Springbok
# Processing record 237 for the city: Samdari
# Record found for city id: 1257528 with city name : Samdari
# Processing record 238 for the city: Rio Grande
# Record found for city id: 3451138 with city name : Rio Grande
# Processing record 239 for the city: Sur
# Record found for city id: 286245 with city name : Sur
# Processing record 240 for the city: San Quintin
# Record found for city id: 3984997 with city name : San Quintin
# Processing record 241 for the city: Rungata
# No weather record found for city: Rungata
# Processing record 242 for the city: Ostrzeszow
# Record found for city id: 3089670 with city name : Ostrzeszow
# Processing record 243 for the city: Nome
# Record found for city id: 5870133 with city name : Nome
# Processing record 244 for the city: Mount Isa
# Record found for city id: 2065594 with city name : Mount Isa
# Processing record 245 for the city: Umzimvubu
# No weather record found for city: Umzimvubu
# Processing record 246 for the city: Limon
# Record found for city id: 3622247 with city name : Limon
# Processing record 247 for the city: Cananeia
# Record found for city id: 3467609 with city name : Cananeia
# Processing record 248 for the city: Zhanakorgan
# Record found for city id: 1517323 with city name : Zhanakorgan
# Processing record 249 for the city: Kamenskoye
# No weather record found for city: Kamenskoye
# Processing record 250 for the city: Brae
# Record found for city id: 2654970 with city name : Brae
# Processing record 251 for the city: Grand River South East
# No weather record found for city: Grand River South East
# Processing record 252 for the city: Jalingo
# Record found for city id: 2336589 with city name : Jalingo
# Processing record 253 for the city: Ulaangom
# Record found for city id: 1515029 with city name : Ulaangom
# Processing record 254 for the city: Herrin
# Record found for city id: 4240540 with city name : Herrin
# Processing record 255 for the city: Rawson
# Record found for city id: 3839307 with city name : Rawson
# Processing record 256 for the city: Taganak
# Record found for city id: 1684606 with city name : Taganak
# Processing record 257 for the city: Deori
# Record found for city id: 1273201 with city name : Deori
# Processing record 258 for the city: Lomovka
# Record found for city id: 534313 with city name : Lomovka
# Processing record 259 for the city: Vanimo
# Record found for city id: 2084442 with city name : Vanimo
# Processing record 260 for the city: Santiago Del Estero
# Record found for city id: 3835869 with city name : Santiago Del Estero
# Processing record 261 for the city: Tsabong
# Record found for city id: 932987 with city name : Tsabong
# Processing record 262 for the city: Teeli
# Record found for city id: 1489828 with city name : Teeli
# Processing record 263 for the city: Haines Junction
# Record found for city id: 5969025 with city name : Haines Junction
# Processing record 264 for the city: Kaitangata
# Record found for city id: 2208248 with city name : Kaitangata
# Processing record 265 for the city: Mnogovershinnyy
# Record found for city id: 2019935 with city name : Mnogovershinnyy
# Processing record 266 for the city: Surin
# Record found for city id: 1606030 with city name : Surin
# Processing record 267 for the city: Mobaye
# Record found for city id: 237478 with city name : Mobaye
# Processing record 268 for the city: Solnechnyy
# Record found for city id: 2016307 with city name : Solnechnyy
# Processing record 269 for the city: Hengshan
# Record found for city id: 2036920 with city name : Hengshan
# Processing record 270 for the city: Sarankhola
# Record found for city id: 1185239 with city name : Sarankhola
# Processing record 271 for the city: Riyadh
# Record found for city id: 108410 with city name : Riyadh
# Processing record 272 for the city: Baruun-Urt
# Record found for city id: 2032614 with city name : Baruun-Urt
# Processing record 273 for the city: Bambanglipuro
# Record found for city id: 1650434 with city name : Bambanglipuro
# Processing record 274 for the city: Tiksi
# Record found for city id: 2015306 with city name : Tiksi
# Processing record 275 for the city: Cidreira
# Record found for city id: 3466165 with city name : Cidreira
# Processing record 276 for the city: Vila Velha
# Record found for city id: 3445026 with city name : Vila Velha
# Processing record 277 for the city: Alice Springs
# Record found for city id: 2077895 with city name : Alice Springs
# Processing record 278 for the city: Luderitz
# Record found for city id: 3355672 with city name : Luderitz
# Processing record 279 for the city: Comodoro Rivadavia
# Record found for city id: 3860443 with city name : Comodoro Rivadavia
# Processing record 280 for the city: Huarmey
# Record found for city id: 3939168 with city name : Huarmey
# Processing record 281 for the city: Okhotsk
# Record found for city id: 2122605 with city name : Okhotsk
# Processing record 282 for the city: Tateyama
# Record found for city id: 1850523 with city name : Tateyama
# Processing record 283 for the city: Coffs Harbour
# Record found for city id: 2171085 with city name : Coffs Harbour
# Processing record 284 for the city: Rosario
# Record found for city id: 3838583 with city name : Rosario
# Processing record 285 for the city: Surt
# Record found for city id: 2210554 with city name : Surt
# Processing record 286 for the city: Lazarev
# Record found for city id: 2123836 with city name : Lazarev
# Processing record 287 for the city: Namatanai
# Record found for city id: 2090021 with city name : Namatanai
# Processing record 288 for the city: Palu
# Record found for city id: 1633034 with city name : Palu
# Processing record 289 for the city: Tshikapa
# Record found for city id: 204953 with city name : Tshikapa
# Processing record 290 for the city: Renala Khurd
# Record found for city id: 1166933 with city name : Renala Khurd
# Processing record 291 for the city: Bambous Virieux
# Record found for city id: 1106677 with city name : Bambous Virieux
# Processing record 292 for the city: Atherton
# Record found for city id: 2656847 with city name : Atherton
# Processing record 293 for the city: Ponta Do Sol
# Record found for city id: 2264557 with city name : Ponta Do Sol
# Processing record 294 for the city: Ituni
# No weather record found for city: Ituni
# Processing record 295 for the city: Yatou
# Record found for city id: 1786855 with city name : Yatou
# Processing record 296 for the city: Eureka
# Record found for city id: 5563397 with city name : Eureka
# Processing record 297 for the city: Lavrentiya
# Record found for city id: 4031637 with city name : Lavrentiya
# Processing record 298 for the city: Peniche
# Record found for city id: 2264923 with city name : Peniche
# Processing record 299 for the city: Coihaique
# Record found for city id: 3894426 with city name : Coihaique
# Processing record 300 for the city: Lorengau
# Record found for city id: 2092164 with city name : Lorengau
# Processing record 301 for the city: New Norfolk
# Record found for city id: 2155415 with city name : New Norfolk
# Processing record 302 for the city: Doha
# Record found for city id: 290030 with city name : Doha
# Processing record 303 for the city: Andevoranto
# No weather record found for city: Andevoranto
# Processing record 304 for the city: Ihosy
# Record found for city id: 1064275 with city name : Ihosy
# Processing record 305 for the city: Ginda
# Record found for city id: 1253628 with city name : Ginda
# Processing record 306 for the city: Necochea
# Record found for city id: 3430443 with city name : Necochea
# Processing record 307 for the city: Masvingo
# Record found for city id: 886763 with city name : Masvingo
# Processing record 308 for the city: Prachuap Khiri Khan
# Record found for city id: 1151073 with city name : Prachuap Khiri Khan
# Processing record 309 for the city: Oriximina
# Record found for city id: 3393471 with city name : Oriximina
# Processing record 310 for the city: San Vicente
# Record found for city id: 3428068 with city name : San Vicente
# Processing record 311 for the city: Tura
# Record found for city id: 1254046 with city name : Tura
# Processing record 312 for the city: Beringovskiy
# Record found for city id: 2126710 with city name : Beringovskiy
# Processing record 313 for the city: Ahuimanu
# Record found for city id: 5856516 with city name : Ahuimanu
# Processing record 314 for the city: Atbasar
# Record found for city id: 1526038 with city name : Atbasar
# Processing record 315 for the city: Gat
# Record found for city id: 293842 with city name : Gat
# Processing record 316 for the city: Atar
# Record found for city id: 2381334 with city name : Atar
# Processing record 317 for the city: Bataipora
# Record found for city id: 3470338 with city name : Bataipora
# Processing record 318 for the city: Hurghada
# Record found for city id: 361291 with city name : Hurghada
# Processing record 319 for the city: Swan Hill
# Record found for city id: 2147756 with city name : Swan Hill
# Processing record 320 for the city: Tarko-Sale
# Record found for city id: 1490085 with city name : Tarko-Sale
# Processing record 321 for the city: Buala
# Record found for city id: 2109528 with city name : Buala
# Processing record 322 for the city: Shache
# Record found for city id: 1280037 with city name : Shache
# Processing record 323 for the city: Camacha
# Record found for city id: 2270385 with city name : Camacha
# Processing record 324 for the city: Jumla
# Record found for city id: 1283285 with city name : Jumla
# Processing record 325 for the city: Moree
# Record found for city id: 2156927 with city name : Moree
# Processing record 326 for the city: Ribeira Grande
# Record found for city id: 3372707 with city name : Ribeira Grande
# Processing record 327 for the city: Fevralsk
# No weather record found for city: Fevralsk
# Processing record 328 for the city: Lalmohan
# Record found for city id: 1185251 with city name : Lalmohan
# Processing record 329 for the city: Labuhan
# Record found for city id: 8079926 with city name : Labuhan
# Processing record 330 for the city: Nizhneyansk
# No weather record found for city: Nizhneyansk
# Processing record 331 for the city: Coquimbo
# Record found for city id: 3893629 with city name : Coquimbo
# Processing record 332 for the city: Attawapiskat
# No weather record found for city: Attawapiskat
# Processing record 333 for the city: Voyvozh
# Record found for city id: 471308 with city name : Voyvozh
# Processing record 334 for the city: Purpe
# Record found for city id: 1539210 with city name : Purpe
# Processing record 335 for the city: Zeya
# Record found for city id: 2012593 with city name : Zeya
# Processing record 336 for the city: Boende
# Record found for city id: 218680 with city name : Boende
# Processing record 337 for the city: Mahebourg
# Record found for city id: 934322 with city name : Mahebourg
# Processing record 338 for the city: Kidal
# Record found for city id: 2455290 with city name : Kidal
# Processing record 339 for the city: Larsnes
# Record found for city id: 3148133 with city name : Larsnes
# Processing record 340 for the city: Saint-Augustin
# Record found for city id: 6137462 with city name : Saint-Augustin
# Processing record 341 for the city: Raga
# Record found for city id: 368246 with city name : Raga
# Processing record 342 for the city: Sai Buri
# Record found for city id: 1606851 with city name : Sai Buri
# Processing record 343 for the city: Saint Anthony
# Record found for city id: 5044290 with city name : Saint Anthony
# Processing record 344 for the city: Challans
# Record found for city id: 3027513 with city name : Challans
# Processing record 345 for the city: Sioux Lookout
# Record found for city id: 6148373 with city name : Sioux Lookout
# Processing record 346 for the city: Tukrah
# Record found for city id: 88834 with city name : Tukrah
# Processing record 347 for the city: Yar-Sale
# Record found for city id: 1486321 with city name : Yar-Sale
# Processing record 348 for the city: Kununurra
# Record found for city id: 2068110 with city name : Kununurra
# Processing record 349 for the city: Sisimiut
# Record found for city id: 3419842 with city name : Sisimiut
# Processing record 350 for the city: Faanui
# Record found for city id: 4034551 with city name : Faanui
# Processing record 351 for the city: Kanigiri
# Record found for city id: 1268059 with city name : Kanigiri
# Processing record 352 for the city: Owo
# Record found for city id: 2325314 with city name : Owo
# Processing record 353 for the city: Bay Roberts
# Record found for city id: 5895424 with city name : Bay Roberts
# Processing record 354 for the city: Sayyan
# Record found for city id: 70979 with city name : Sayyan
# Processing record 355 for the city: Norden
# Record found for city id: 2862118 with city name : Norden
# Processing record 356 for the city: Marcona
# No weather record found for city: Marcona
# Processing record 357 for the city: Tuatapere
# Record found for city id: 2180815 with city name : Tuatapere
# Processing record 358 for the city: Eirunepe
# Record found for city id: 3664321 with city name : Eirunepe
# Processing record 359 for the city: Maningrida
# Record found for city id: 2067089 with city name : Maningrida
# Processing record 360 for the city: Tuktoyaktuk
# Record found for city id: 6170031 with city name : Tuktoyaktuk
# Processing record 361 for the city: Harper
# Record found for city id: 2276492 with city name : Harper
# Processing record 362 for the city: Haverfordwest
# Record found for city id: 2647311 with city name : Haverfordwest
# Processing record 363 for the city: Mingguang
# Record found for city id: 1800519 with city name : Mingguang
# Processing record 364 for the city: Vao
# Record found for city id: 2137773 with city name : Vao
# Processing record 365 for the city: Amderma
# No weather record found for city: Amderma
# Processing record 366 for the city: Geraldton
# Record found for city id: 2070998 with city name : Geraldton
# Processing record 367 for the city: Hualmay
# Record found for city id: 3939761 with city name : Hualmay
# Processing record 368 for the city: Blagoyevo
# Record found for city id: 576093 with city name : Blagoyevo
# Processing record 369 for the city: Sola
# Record found for city id: 2134814 with city name : Sola
# Processing record 370 for the city: Sao Filipe
# Record found for city id: 3374210 with city name : Sao Filipe
# Processing record 371 for the city: Chernyshevskiy
# Record found for city id: 2025456 with city name : Chernyshevskiy
# Processing record 372 for the city: Tumannyy
# No weather record found for city: Tumannyy
# Processing record 373 for the city: Luancheng
# Record found for city id: 1802204 with city name : Luancheng
# Processing record 374 for the city: Bilma
# Record found for city id: 2446796 with city name : Bilma
# Processing record 375 for the city: Batemans Bay
# Record found for city id: 2176639 with city name : Batemans Bay
# Processing record 376 for the city: Asfi
# Record found for city id: 2537881 with city name : Asfi
# Processing record 377 for the city: Te Anau
# Record found for city id: 2181625 with city name : Te Anau
# Processing record 378 for the city: Thinadhoo
# Record found for city id: 1337610 with city name : Thinadhoo
# Processing record 379 for the city: San Patricio
# Record found for city id: 4726521 with city name : San Patricio
# Processing record 380 for the city: Kaohsiung
# Record found for city id: 1673820 with city name : Kaohsiung
# Processing record 381 for the city: Maxixe
# Record found for city id: 1039536 with city name : Maxixe
# Processing record 382 for the city: Samusu
# No weather record found for city: Samusu
# Processing record 383 for the city: Thompson
# Record found for city id: 6165406 with city name : Thompson
# Processing record 384 for the city: Pandan
# Record found for city id: 1695546 with city name : Pandan
# Processing record 385 for the city: Kill
# Record found for city id: 2963388 with city name : Kill
# Processing record 386 for the city: Miranorte
# No weather record found for city: Miranorte
# Processing record 387 for the city: Chokwe
# Record found for city id: 1048364 with city name : Chokwe
# Processing record 388 for the city: San Cristobal
# Record found for city id: 3628473 with city name : San Cristobal
# Processing record 389 for the city: Maun
# Record found for city id: 933366 with city name : Maun
# Processing record 390 for the city: Olafsvik
# Record found for city id: 3414079 with city name : Olafsvik
# Processing record 391 for the city: Jambi
# Record found for city id: 1642858 with city name : Jambi
# Processing record 392 for the city: Mys Shmidta
# No weather record found for city: Mys Shmidta
# Processing record 393 for the city: Riachao Das Neves
# Record found for city id: 3451478 with city name : Riachao Das Neves
# Processing record 394 for the city: Shenjiamen
# Record found for city id: 1795632 with city name : Shenjiamen
# Processing record 395 for the city: Mergui
# No weather record found for city: Mergui
# Processing record 396 for the city: Pakdasht
# Record found for city id: 32767 with city name : Pakdasht
# Processing record 397 for the city: Makakilo City
# Record found for city id: 5850554 with city name : Makakilo City
# Processing record 398 for the city: Clyde
# Record found for city id: 5150651 with city name : Clyde
# Processing record 399 for the city: Tari
# Record found for city id: 2322495 with city name : Tari
# Processing record 400 for the city: Chicama
# Record found for city id: 3698359 with city name : Chicama
# Processing record 401 for the city: Varnavino
# Record found for city id: 476982 with city name : Varnavino
# Processing record 402 for the city: Guilin
# Record found for city id: 1809498 with city name : Guilin
# Processing record 403 for the city: Havre-Saint-Pierre
# Record found for city id: 5972291 with city name : Havre-Saint-Pierre
# Processing record 404 for the city: Esmeraldas
# Record found for city id: 3464008 with city name : Esmeraldas
# Processing record 405 for the city: Iwaki
# Record found for city id: 2112539 with city name : Iwaki
# Processing record 406 for the city: Bayji
# Record found for city id: 97783 with city name : Bayji
# Processing record 407 for the city: Numan
# Record found for city id: 2328617 with city name : Numan
# Processing record 408 for the city: Eyl
# Record found for city id: 60019 with city name : Eyl
# Processing record 409 for the city: Kruisfontein
# Record found for city id: 986717 with city name : Kruisfontein
# Processing record 410 for the city: Kollo
# Record found for city id: 2442248 with city name : Kollo
# Processing record 411 for the city: Tagbina
# Record found for city id: 1684491 with city name : Tagbina
# Processing record 412 for the city: Vestmannaeyjar
# Record found for city id: 3412093 with city name : Vestmannaeyjar
# Processing record 413 for the city: San Jose
# Record found for city id: 5392171 with city name : San Jose
# Processing record 414 for the city: Arman
# Record found for city id: 2127060 with city name : Arman
# Processing record 415 for the city: Valparaiso
# Record found for city id: 3868626 with city name : Valparaiso
# Processing record 416 for the city: Santa Engracia
# Record found for city id: 3108269 with city name : Santa Engracia
# Processing record 417 for the city: Manta
# Record found for city id: 3654410 with city name : Manta
# Processing record 418 for the city: Toliary
# No weather record found for city: Toliary
# Processing record 419 for the city: Scottsburgh
# No weather record found for city: Scottsburgh
# Processing record 420 for the city: Gemena
# Record found for city id: 2315728 with city name : Gemena
# Processing record 421 for the city: Svetlogorsk
# Record found for city id: 10722858 with city name : Svetlogorsk
# Processing record 422 for the city: Abu Samrah
# Record found for city id: 172515 with city name : Abu Samrah
# Processing record 423 for the city: Louisbourg
# No weather record found for city: Louisbourg
# Processing record 424 for the city: Skibbereen
# Record found for city id: 2961459 with city name : Skibbereen
# Processing record 425 for the city: Vittorio Veneto
# Record found for city id: 3164028 with city name : Vittorio Veneto
# Processing record 426 for the city: Farmington
# Record found for city id: 5467328 with city name : Farmington
# Processing record 427 for the city: Torrington
# Record found for city id: 4844309 with city name : Torrington
# Processing record 428 for the city: Nhulunbuy
# Record found for city id: 2064735 with city name : Nhulunbuy
# Processing record 429 for the city: Glyadyanskoye
# Record found for city id: 1506499 with city name : Glyadyanskoye
# Processing record 430 for the city: Satitoa
# No weather record found for city: Satitoa
# Processing record 431 for the city: Enid
# Record found for city id: 4535961 with city name : Enid
# Processing record 432 for the city: Richards Bay
# Record found for city id: 962367 with city name : Richards Bay
# Processing record 433 for the city: Usinsk
# Record found for city id: 863061 with city name : Usinsk
# Processing record 434 for the city: Warqla
# No weather record found for city: Warqla
# Processing record 435 for the city: Luganville
# Record found for city id: 2136150 with city name : Luganville
# Processing record 436 for the city: Chagda
# No weather record found for city: Chagda
# Processing record 437 for the city: Nicolas Bravo
# Record found for city id: 3522742 with city name : Nicolas Bravo
# Processing record 438 for the city: Paamiut
# Record found for city id: 3421193 with city name : Paamiut
# Processing record 439 for the city: Tabanan
# Record found for city id: 1625708 with city name : Tabanan
# Processing record 440 for the city: Cheuskiny
# No weather record found for city: Cheuskiny
# Processing record 441 for the city: Alanya
# Record found for city id: 324190 with city name : Alanya
# Processing record 442 for the city: Safaqis
# No weather record found for city: Safaqis
# Processing record 443 for the city: Ojinaga
# Record found for city id: 3994469 with city name : Ojinaga
# Processing record 444 for the city: Honningsvag
# Record found for city id: 779554 with city name : Honningsvag
# Processing record 445 for the city: Saint Marys
# Record found for city id: 4220629 with city name : Saint Marys
# Processing record 446 for the city: Stornoway
# Record found for city id: 2636790 with city name : Stornoway
# Processing record 447 for the city: Boa Vista
# Record found for city id: 3664980 with city name : Boa Vista
# Processing record 448 for the city: Galiwinku
# No weather record found for city: Galiwinku
# Processing record 449 for the city: Olga
# Record found for city id: 2018553 with city name : Olga
# Processing record 450 for the city: Tual
# Record found for city id: 1623197 with city name : Tual
# Processing record 451 for the city: Soledade
# Record found for city id: 3447423 with city name : Soledade
# Processing record 452 for the city: Nouadhibou
# Record found for city id: 2377457 with city name : Nouadhibou
# Processing record 453 for the city: Pano Aqil
# Record found for city id: 1168412 with city name : Pano Aqil
# Processing record 454 for the city: Mitchell
# Record found for city id: 5229794 with city name : Mitchell
# Processing record 455 for the city: Plettenberg Bay
# Record found for city id: 964712 with city name : Plettenberg Bay
# Processing record 456 for the city: Marathon
# Record found for city id: 5261790 with city name : Marathon
# Processing record 457 for the city: Vila Franca Do Campo
# Record found for city id: 3372472 with city name : Vila Franca Do Campo
# Processing record 458 for the city: Cam Ranh
# Record found for city id: 1586350 with city name : Cam Ranh
# Processing record 459 for the city: Tomatlan
# Record found for city id: 3981391 with city name : Tomatlan
# Processing record 460 for the city: Shitanjing
# Record found for city id: 1794971 with city name : Shitanjing
# Processing record 461 for the city: Fenoarivo
# ...
# Processing record 462 for the city: Neyshabur
# Record found for city id: 122285 with city name : Neyshabur
# Processing record 463 for the city: Carutapera
# Record found for city id: 3402648 with city name : Carutapera
# Processing record 464 for the city: Tocopilla
# Record found for city id: 3869716 with city name : Tocopilla
# Processing record 465 for the city: Port Hedland
# Record found for city id: 2063042 with city name : Port Hedland
# Processing record 466 for the city: Leh
# Record found for city id: 1264976 with city name : Leh
# Processing record 467 for the city: Novaya Chigla
# Record found for city id: 519777 with city name : Novaya Chigla
# Processing record 468 for the city: Dzhusaly
# No weather record found for city: Dzhusaly
# Processing record 469 for the city: Kousseri
# Record found for city id: 2229798 with city name : Kousseri
# Processing record 470 for the city: Marsh Harbour
# Record found for city id: 3571913 with city name : Marsh Harbour
# Processing record 471 for the city: Strezhevoy
# Record found for city id: 1490796 with city name : Strezhevoy
# Processing record 472 for the city: Yasnyy
# Record found for city id: 468657 with city name : Yasnyy
# Processing record 473 for the city: Ola
# Record found for city id: 2122574 with city name : Ola
# Processing record 474 for the city: Lindi
# Record found for city id: 878281 with city name : Lindi
# Processing record 475 for the city: Santa Fe
# Record found for city id: 3836277 with city name : Santa Fe
# Processing record 476 for the city: Half Moon Bay
# Record found for city id: 5354943 with city name : Half Moon Bay
# Processing record 477 for the city: Veracruz
# Record found for city id: 3514780 with city name : Veracruz
# Processing record 478 for the city: Foki
# Record found for city id: 562580 with city name : Foki
# Processing record 479 for the city: Grand Gaube
# Record found for city id: 934479 with city name : Grand Gaube
# Processing record 480 for the city: Aviles
# Record found for city id: 3129135 with city name : Aviles
# Processing record 481 for the city: Bani Walid
# Record found for city id: 2218840 with city name : Bani Walid
# Processing record 482 for the city: Lujiang
# Record found for city id: 1802068 with city name : Lujiang
# Processing record 483 for the city: Kaeo
# Record found for city id: 2189343 with city name : Kaeo
# Processing record 484 for the city: Mapiripan
# Record found for city id: 3792394 with city name : Mapiripan
# Processing record 485 for the city: Flin Flon
# Record found for city id: 5954718 with city name : Flin Flon
# Processing record 486 for the city: Rognan
# Record found for city id: 3141548 with city name : Rognan
# Processing record 487 for the city: Sibolga
# Record found for city id: 1213855 with city name : Sibolga
# Processing record 488 for the city: Aljezur
# Record found for city id: 2271968 with city name : Aljezur
# Processing record 489 for the city: Morondava
# Record found for city id: 1058381 with city name : Morondava
# Processing record 490 for the city: Kambove
# Record found for city id: 923058 with city name : Kambove
# Processing record 491 for the city: Sampit
# Record found for city id: 1628884 with city name : Sampit
# Processing record 492 for the city: Oum Hadjer
# Record found for city id: 2426370 with city name : Oum Hadjer
# Processing record 493 for the city: Dothan
# Record found for city id: 4059102 with city name : Dothan
# Processing record 494 for the city: Cayenne
# Record found for city id: 3382160 with city name : Cayenne
# Processing record 495 for the city: Saint-Joseph
# Record found for city id: 6690296 with city name : Saint-Joseph
# Processing record 496 for the city: Staroutkinsk
# Record found for city id: 488593 with city name : Staroutkinsk
# Processing record 497 for the city: Simbahan
# Record found for city id: 1695180 with city name : Simbahan
# Processing record 498 for the city: Bartlett
# Record found for city id: 4604183 with city name : Bartlett
# Processing record 499 for the city: Ilulissat
# Record found for city id: 3423146 with city name : Ilulissat
# Processing record 500 for the city: Bacungan
# Record found for city id: 1729456 with city name : Bacungan
# Processing record 501 for the city: Cabedelo
# Record found for city id: 3404558 with city name : Cabedelo
# Processing record 502 for the city: Doume
# Record found for city id: 2232497 with city name : Doume
# Processing record 503 for the city: Glenn Heights
# Record found for city id: 4693726 with city name : Glenn Heights
# Processing record 504 for the city: Bara
# Record found for city id: 2347758 with city name : Bara
# Processing record 505 for the city: Telemaco Borba
# Record found for city id: 3446652 with city name : Telemaco Borba
# Processing record 506 for the city: Sawtell
# Record found for city id: 2150163 with city name : Sawtell
# Processing record 507 for the city: Khingansk
# Record found for city id: 2022454 with city name : Khingansk
# Processing record 508 for the city: Fare
# Record found for city id: 4034496 with city name : Fare
# Processing record 509 for the city: Neepawa
# Record found for city id: 6086673 with city name : Neepawa
# Processing record 510 for the city: Dingle
# Record found for city id: 1714733 with city name : Dingle
# Processing record 511 for the city: Flinders
# Record found for city id: 6255012 with city name : Flinders
# Processing record 512 for the city: Nambutalai
# Record found for city id: 1262032 with city name : Nambutalai
# Processing record 513 for the city: Barbar
# No weather record found for city: Barbar
# Processing record 514 for the city: Yulara
# Record found for city id: 6355222 with city name : Yulara
# Processing record 515 for the city: Bababe
# No weather record found for city: Bababe
# Processing record 516 for the city: Luwuk
# Record found for city id: 1637001 with city name : Luwuk
# Processing record 517 for the city: Una
# Record found for city id: 1253783 with city name : Una
# Processing record 518 for the city: Calabozo
# Record found for city id: 3647444 with city name : Calabozo
# Processing record 519 for the city: Ormara
# Record found for city id: 1168700 with city name : Ormara
# Processing record 520 for the city: Champerico
# Record found for city id: 3598787 with city name : Champerico
# Processing record 521 for the city: Santa Isabel
# Record found for city id: 3450188 with city name : Santa Isabel
# Processing record 522 for the city: Vaitape
# Record found for city id: 4033077 with city name : Vaitape
# Processing record 523 for the city: Sotik
# Record found for city id: 179888 with city name : Sotik
# Processing record 524 for the city: Kaiyuan
# Record found for city id: 1804850 with city name : Kaiyuan
# Processing record 525 for the city: Avera
# Record found for city id: 4231997 with city name : Avera
# Processing record 526 for the city: Dauphin
# Record found for city id: 5935341 with city name : Dauphin
# Processing record 527 for the city: Ambon
# Record found for city id: 1651531 with city name : Ambon
# Processing record 528 for the city: Homer
# Record found for city id: 5864145 with city name : Homer
# Processing record 529 for the city: Hohhot
# Record found for city id: 2036892 with city name : Hohhot
# Processing record 530 for the city: Shingu
# Record found for city id: 1847947 with city name : Shingu
# Processing record 531 for the city: Umm Kaddadah
# Record found for city id: 364933 with city name : Umm Kaddadah
# Processing record 532 for the city: Moron
# Record found for city id: 3430545 with city name : Moron
# Processing record 533 for the city: Wulanhaote
# No weather record found for city: Wulanhaote
# Processing record 534 for the city: Samfya
# Record found for city id: 899274 with city name : Samfya
# Processing record 535 for the city: Bengkulu
# Record found for city id: 1649150 with city name : Bengkulu
# Processing record 536 for the city: Veraval
# Record found for city id: 1253237 with city name : Veraval
# Processing record 537 for the city: Quatre Cocos
# Record found for city id: 1106643 with city name : Quatre Cocos
# Processing record 538 for the city: Kortkeros
# Record found for city id: 544397 with city name : Kortkeros
# Processing record 539 for the city: Najran
# Record found for city id: 103630 with city name : Najran
# Processing record 540 for the city: Kindu
# Record found for city id: 212902 with city name : Kindu
# Processing record 541 for the city: Bisho
# Record found for city id: 1019330 with city name : Bisho
# Processing record 542 for the city: Vuktyl
# Record found for city id: 470905 with city name : Vuktyl
# Processing record 543 for the city: Grand-Santi
# Record found for city id: 3381538 with city name : Grand-Santi
# Processing record 544 for the city: Ulaanbaatar
# Record found for city id: 2028462 with city name : Ulaanbaatar
# Processing record 545 for the city: Fraserburgh
# Record found for city id: 2649089 with city name : Fraserburgh
# Processing record 546 for the city: Kano
# Record found for city id: 2335204 with city name : Kano
# Processing record 547 for the city: Lodja
# Record found for city id: 211647 with city name : Lodja
# Processing record 548 for the city: Svetlyy Yar
# Record found for city id: 485643 with city name : Svetlyy Yar
# Processing record 549 for the city: Filadelfia
# Record found for city id: 4560349 with city name : Filadelfia
# Processing record 550 for the city: Berdigestyakh
# Record found for city id: 2026861 with city name : Berdigestyakh
# Processing record 551 for the city: Kosgi
# No weather record found for city: Kosgi
# Processing record 552 for the city: Verkhnetulomskiy
# Record found for city id: 475469 with city name : Verkhnetulomskiy
# Processing record 553 for the city: Innisfail
# Record found for city id: 2162683 with city name : Innisfail
# Processing record 554 for the city: Gharb
# No weather record found for city: Gharb
# Processing record 555 for the city: Gander
# Record found for city id: 5959335 with city name : Gander
# Processing record 556 for the city: Usakos
# Record found for city id: 3352461 with city name : Usakos
# Processing record 557 for the city: Evensk
# Record found for city id: 2125693 with city name : Evensk
# Processing record 558 for the city: Laguna
# Record found for city id: 5364271 with city name : Laguna
# Processing record 559 for the city: Longlac
# No weather record found for city: Longlac
# Processing record 560 for the city: Altar
# Record found for city id: 4018700 with city name : Altar
# Processing record 561 for the city: Port Hawkesbury
# Record found for city id: 6111867 with city name : Port Hawkesbury
# Processing record 562 for the city: Zhanatas
# No weather record found for city: Zhanatas
# Processing record 563 for the city: Port Said
# Record found for city id: 358619 with city name : Port Said
# Processing record 564 for the city: Mutoko
# Record found for city id: 884927 with city name : Mutoko
# Processing record 565 for the city: Asau
# Record found for city id: 686090 with city name : Asau
# Processing record 566 for the city: Beloha
# Record found for city id: 1067565 with city name : Beloha
# Processing record 567 for the city: Bolungarvik
# No weather record found for city: Bolungarvik
# Processing record 568 for the city: Namtsy
# Record found for city id: 2019488 with city name : Namtsy
# Processing record 569 for the city: Azangaro
# Record found for city id: 3946937 with city name : Azangaro
# Processing record 570 for the city: Mehamn
# Record found for city id: 778707 with city name : Mehamn
# Processing record 571 for the city: Zavodouspenskoye
# Record found for city id: 1485354 with city name : Zavodouspenskoye
# Processing record 572 for the city: Qinzhou
# Record found for city id: 1797551 with city name : Qinzhou
# Processing record 573 for the city: Dabat
# Record found for city id: 340358 with city name : Dabat
# Processing record 574 for the city: Klaksvik
# Record found for city id: 2618795 with city name : Klaksvik
# Processing record 575 for the city: Tevaitoa
# Record found for city id: 4033375 with city name : Tevaitoa
# Processing record 576 for the city: Tilichiki
# Record found for city id: 2120591 with city name : Tilichiki
# Processing record 577 for the city: Saint-Pierre
# Record found for city id: 935214 with city name : Saint-Pierre
# Processing record 578 for the city: Korla
# Record found for city id: 1529376 with city name : Korla
# Processing record 579 for the city: Marawi
# Record found for city id: 1701054 with city name : Marawi
# Processing record 580 for the city: Chapais
# Record found for city id: 5919850 with city name : Chapais
# Processing record 581 for the city: Angoche
# Record found for city id: 1052944 with city name : Angoche
# Processing record 582 for the city: Redlands
# Record found for city id: 5386754 with city name : Redlands
# Processing record 583 for the city: Mankono
# Record found for city id: 2284589 with city name : Mankono
# Processing record 584 for the city: Skiros
# No weather record found for city: Skiros
# Processing record 585 for the city: Puerto Gaitan
# Record found for city id: 3769976 with city name : Puerto Gaitan
# Processing record 586 for the city: Puri
# Record found for city id: 1259184 with city name : Puri
# Processing record 587 for the city: Igrim
# Record found for city id: 1505965 with city name : Igrim
# Processing record 588 for the city: Santa Marta
# Record found for city id: 3668605 with city name : Santa Marta
# Processing record 589 for the city: Amuntai
# Record found for city id: 1651461 with city name : Amuntai
# Processing record 590 for the city: Nelson Bay
# Record found for city id: 2155562 with city name : Nelson Bay
# Processing record 591 for the city: Agulu
# Record found for city id: 2351740 with city name : Agulu
# Processing record 592 for the city: Roald
# Record found for city id: 3141667 with city name : Roald
# Processing record 593 for the city: Selma
# Record found for city id: 5394329 with city name : Selma
# Processing record 594 for the city: Iskateley
# Record found for city id: 866062 with city name : Iskateley
# Processing record 595 for the city: Marfino
# Record found for city id: 529368 with city name : Marfino
# Processing record 596 for the city: Boyolangu
# Record found for city id: 1648082 with city name : Boyolangu
# Processing record 597 for the city: Maloy
# Record found for city id: 3146487 with city name : Maloy
# Processing record 598 for the city: Vagamo
# Record found for city id: 3133053 with city name : Vagamo
# Processing record 599 for the city: Calatayud
# Record found for city id: 3127047 with city name : Calatayud
# Processing record 600 for the city: Keningau
# Record found for city id: 1734098 with city name : Keningau
# Processing record 601 for the city: Berbera
# Record found for city id: 64435 with city name : Berbera
# Processing record 602 for the city: Lata
# Record found for city id: 2738381 with city name : Lata
# Processing record 603 for the city: Tsienyane
# No weather record found for city: Tsienyane
# Processing record 604 for the city: Gombong
# Record found for city id: 1643920 with city name : Gombong
# Processing record 605 for the city: Jetalsar
# Record found for city id: 1269070 with city name : Jetalsar
# Processing record 606 for the city: Wexford
# Record found for city id: 2960964 with city name : Wexford
# Processing record 607 for the city: Aksay
# Record found for city id: 583673 with city name : Aksay
# Processing record 608 for the city: Serowe
# Record found for city id: 933088 with city name : Serowe
# Processing record 609 for the city: Marzuq
# Record found for city id: 72181 with city name : Marzuq
# Processing record 610 for the city: Bela
# Record found for city id: 1276574 with city name : Bela
# Processing record 611 for the city: Karratha
# Record found for city id: 6620339 with city name : Karratha
# Processing record 612 for the city: Galich
# Record found for city id: 562161 with city name : Galich
# Processing record 613 for the city: Manga
# Record found for city id: 2358100 with city name : Manga
# Processing record 614 for the city: Pringsewu
# Record found for city id: 1630639 with city name : Pringsewu
# Processing record 615 for the city: Darhan
# Record found for city id: 2031964 with city name : Darhan
# Processing record 616 for the city: Kamenka
# Record found for city id: 553766 with city name : Kamenka
# ---------------------------------------
# Processing Complete

# %%
random_search_data
# Out:
# [{'coord': {'lon': -114.35, 'lat': 62.46},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 0.9,
#    'feels_like': -7.4,
#    'temp_min': -0.4,
#    'temp_max': 1.99,
#    'pressure': 1018,
#    'humidity': 84},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 10},
#   'clouds': {'all': 75},
#   'dt': 1604519102,
#   'sys': {'type': 1,
#    'id': 1007,
#    'country': 'CA',
#    'sunrise': 1604503308,
#    'sunset': 1604532008},
#   'timezone': -25200,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 87.24,
#    'feels_like': 93.31,
#    'temp_min': 86,
#    'temp_max': 89.01,
#    'pressure': 1016,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 310},
#   'clouds': {'all': 5},
#   'dt': 1604519188,
#   'sys': {'type': 1,
#    'id': 7151,
#    'country': 'MX',
#    'sunrise': 1604496391,
#    'sunset': 1604536793},
#   'timezone': -25200,
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': -68.3, 'lat': -54.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'feels_like': 58.33,
#    'temp_min': 64.4,
#    'temp_max': 64.4,
#    'pressure': 1000,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1604519400,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1604479029,
#    'sunset': 1604534182},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -155.09, 'lat': 19.73},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.39,
#    'feels_like': 82.44,
#    'temp_min': 75,
#    'temp_max': 80.6,
#    'pressure': 1018,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 220},
#   'clouds': {'all': 90},
#   'dt': 1604519400,
#   'sys': {'type': 1,
#    'id': 7881,
#    'country': 'US',
#    'sunrise': 1604506998,
#    'sunset': 1604547873},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': -80.92, 'lat': 22.95},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'feels_like': 77.74,
#    'temp_min': 77,
#    'temp_max': 77,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 9000,
#   'wind': {'speed': 17.22, 'deg': 60},
#   'clouds': {'all': 75},
#   'dt': 1604519401,
#   'sys': {'type': 1,
#    'id': 7254,
#    'country': 'CU',
#    'sunrise': 1604489436,
#    'sunset': 1604529833},
#   'timezone': -18000,
#   'id': 3547519,
#   'name': 'Martí',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 73.44,
#    'feels_like': 70.12,
#    'temp_min': 73.44,
#    'temp_max': 73.44,
#    'pressure': 1021,
#    'humidity': 75,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 15.28, 'deg': 92},
#   'clouds': {'all': 0},
#   'dt': 1604519401,
#   'sys': {'country': 'PF', 'sunrise': 1604499134, 'sunset': 1604546079},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -73.65, 'lat': -37.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 55.45,
#    'feels_like': 47.8,
#    'temp_min': 55.45,
#    'temp_max': 55.45,
#    'pressure': 1022,
#    'humidity': 63,
#    'sea_level': 1022,
#    'grnd_level': 1012},
#   'visibility': 10000,
#   'wind': {'speed': 10.74, 'deg': 239},
#   'clouds': {'all': 0},
#   'dt': 1604519401,
#   'sys': {'country': 'CL', 'sunrise': 1604483045, 'sunset': 1604532734},
#   'timezone': -10800,
#   'id': 3883457,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': 141.97, 'lat': -38.27},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 48.42,
#    'feels_like': 39.06,
#    'temp_min': 48.42,
#    'temp_max': 48.42,
#    'pressure': 1022,
#    'humidity': 73,
#    'sea_level': 1022,
#    'grnd_level': 1020},
#   'visibility': 10000,
#   'wind': {'speed': 12.73, 'deg': 196},
#   'clouds': {'all': 45},
#   'dt': 1604519401,
#   'sys': {'country': 'AU', 'sunrise': 1604517597, 'sunset': 1604567487},
#   'timezone': 39600,
#   'id': 2171099,
#   'name': 'Codrington',
#   'cod': 200},
#  {'coord': {'lon': 173.17, 'lat': -35.17},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 62.13,
#    'feels_like': 57.25,
#    'temp_min': 62.13,
#    'temp_max': 62.13,
#    'pressure': 1011,
#    'humidity': 93,
#    'sea_level': 1011,
#    'grnd_level': 1009},
#   'visibility': 10000,
#   'wind': {'speed': 14.54, 'deg': 66},
#   'rain': {'1h': 2.05},
#   'clouds': {'all': 100},
#   'dt': 1604519401,
#   'sys': {'country': 'NZ', 'sunrise': 1604510459, 'sunset': 1604559648},
#   'timezone': 46800,
#   'id': 2194098,
#   'name': 'Ahipara',
#   'cod': 200},
#  {'coord': {'lon': -53.81, 'lat': -29.68},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 64.51,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1019,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1604519401,
#   'sys': {'type': 1,
#    'id': 8430,
#    'country': 'BR',
#    'sunrise': 1604479096,
#    'sunset': 1604527160},
#   'timezone': -10800,
#   'id': 3450083,
#   'name': 'Santa Maria',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 81.21,
#    'feels_like': 86.5,
#    'temp_min': 78.8,
#    'temp_max': 82.99,
#    'pressure': 1017,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 11.45, 'deg': 116},
#   'clouds': {'all': 75},
#   'dt': 1604519402,
#   'sys': {'type': 1,
#    'id': 7873,
#    'country': 'US',
#    'sunrise': 1604508192,
#    'sunset': 1604548710},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 32.76, 'lat': 46.84},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'feels_like': 42.01,
#    'temp_min': 50,
#    'temp_max': 50,
#    'pressure': 1026,
#    'humidity': 93},
#   'visibility': 5000,
#   'wind': {'speed': 13.42, 'deg': 40},
#   'clouds': {'all': 0},
#   'dt': 1604519402,
#   'sys': {'type': 1,
#    'id': 8913,
#    'country': 'UA',
#    'sunrise': 1604464559,
#    'sunset': 1604500143},
#   'timezone': 7200,
#   'id': 713676,
#   'name': 'Oleksandrivka',
#   'cod': 200},
#  {'coord': {'lon': -71.34, 'lat': -17.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 69.31,
#    'feels_like': 65.03,
#    'temp_min': 69.31,
#    'temp_max': 69.31,
#    'pressure': 1014,
#    'humidity': 60,
#    'sea_level': 1014,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 10.27, 'deg': 176},
#   'clouds': {'all': 0},
#   'dt': 1604519402,
#   'sys': {'country': 'PE', 'sunrise': 1604484297, 'sunset': 1604530373},
#   'timezone': -18000,
#   'id': 3938415,
#   'name': 'Ilo',
#   'cod': 200},
#  {'coord': {'lon': 135.87, 'lat': -34.73},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 54.12,
#    'feels_like': 45.68,
#    'temp_min': 54.12,
#    'temp_max': 54.12,
#    'pressure': 1027,
#    'humidity': 62,
#    'sea_level': 1027,
#    'grnd_level': 1023},
#   'visibility': 10000,
#   'wind': {'speed': 11.54, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1604519402,
#   'sys': {'country': 'AU', 'sunrise': 1604519452, 'sunset': 1604568560},
#   'timezone': 37800,
#   'id': 2063036,
#   'name': 'Port Lincoln',
#   'cod': 200},
#  {'coord': {'lon': -40.37, 'lat': -14.53},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 65.82,
#    'feels_like': 70.34,
#    'temp_min': 65.82,
#    'temp_max': 65.82,
#    'pressure': 1012,
#    'humidity': 97,
#    'sea_level': 1012,
#    'grnd_level': 926},
#   'visibility': 10000,
#   'wind': {'speed': 1.34, 'deg': 80},
#   'rain': {'1h': 6.484},
#   'clouds': {'all': 100},
#   'dt': 1604519402,
#   'sys': {'country': 'BR', 'sunrise': 1604477096, 'sunset': 1604522709},
#   'timezone': -10800,
#   'id': 3453337,
#   'name': 'Poções',
#   'cod': 200},
#  {'coord': {'lon': 113.63, 'lat': -24.87},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 68,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1013,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 200},
#   'clouds': {'all': 0},
#   'dt': 1604519402,
#   'sys': {'type': 1,
#    'id': 9505,
#    'country': 'AU',
#    'sunrise': 1604525714,
#    'sunset': 1604572973},
#   'timezone': 28800,
#   'id': 2074865,
#   'name': 'Carnarvon',
#   'cod': 200},
#  {'coord': {'lon': -70.92, 'lat': -53.15},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'feels_like': 39.81,
#    'temp_min': 46.4,
#    'temp_max': 46.4,
#    'pressure': 1002,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1604519250,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1604480022,
#    'sunset': 1604534446},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 168.33, 'lat': -46.6},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.01,
#    'feels_like': 57.07,
#    'temp_min': 60.01,
#    'temp_max': 60.01,
#    'pressure': 1005,
#    'humidity': 89},
#   'visibility': 10000,
#   'wind': {'speed': 8.99, 'deg': 241, 'gust': 17},
#   'clouds': {'all': 68},
#   'dt': 1604519403,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1604510156,
#    'sunset': 1604562274},
#   'timezone': 46800,
#   'id': 2206939,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 31.11, 'lat': 70.37},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 39.2,
#    'feels_like': 16.45,
#    'temp_min': 39.2,
#    'temp_max': 39.2,
#    'pressure': 992,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 34.45, 'deg': 230},
#   'clouds': {'all': 75},
#   'dt': 1604519403,
#   'sys': {'type': 1,
#    'id': 1666,
#    'country': 'NO',
#    'sunrise': 1604472438,
#    'sunset': 1604493055},
#   'timezone': 3600,
#   'id': 777019,
#   'name': 'Vardø',
#   'cod': 200},
#  {'coord': {'lon': 97.2, 'lat': 40.28},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 35.67,
#    'feels_like': 22.21,
#    'temp_min': 35.67,
#    'temp_max': 35.67,
#    'pressure': 1026,
#    'humidity': 65,
#    'sea_level': 1026,
#    'grnd_level': 858},
#   'visibility': 10000,
#   'wind': {'speed': 15.97, 'deg': 256},
#   'clouds': {'all': 0},
#   'dt': 1604519403,
#   'sys': {'country': 'CN', 'sunrise': 1604534723, 'sunset': 1604571851},
#   'timezone': 28800,
#   'id': 1528998,
#   'name': 'Yumen',
#   'cod': 200},
#  {'coord': {'lon': 135.31, 'lat': 54.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 13.35,
#    'feels_like': -7.62,
#    'temp_min': 13.35,
#    'temp_max': 13.35,
#    'pressure': 1003,
#    'humidity': 90,
#    'sea_level': 1003,
#    'grnd_level': 1003},
#   'visibility': 10000,
#   'wind': {'speed': 27.09, 'deg': 262},
#   'clouds': {'all': 0},
#   'dt': 1604519403,
#   'sys': {'country': 'RU', 'sunrise': 1604527770, 'sunset': 1604560510},
#   'timezone': 36000,
#   'id': 2025256,
#   'name': 'Chumikan',
#   'cod': 200},
#  {'coord': {'lon': 72.85, 'lat': 29.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.23,
#    'feels_like': 64.17,
#    'temp_min': 72.23,
#    'temp_max': 72.23,
#    'pressure': 1012,
#    'humidity': 19,
#    'sea_level': 1012,
#    'grnd_level': 995},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 175},
#   'clouds': {'all': 0},
#   'dt': 1604519403,
#   'sys': {'country': 'PK', 'sunrise': 1604539467, 'sunset': 1604578795},
#   'timezone': 18000,
#   'id': 1179223,
#   'name': 'Fort Abbas',
#   'cod': 200},
#  {'coord': {'lon': 76.55, 'lat': 60.93},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 35.6,
#    'feels_like': 24.94,
#    'temp_min': 35.6,
#    'temp_max': 35.6,
#    'pressure': 1001,
#    'humidity': 98},
#   'visibility': 10000,
#   'wind': {'speed': 13.42, 'deg': 280, 'gust': 24.61},
#   'clouds': {'all': 90},
#   'dt': 1604519403,
#   'sys': {'type': 1,
#    'id': 8986,
#    'country': 'RU',
#    'sunrise': 1604543470,
#    'sunset': 1604573016},
#   'timezone': 18000,
#   'id': 1497543,
#   'name': 'Nizhnevartovsk',
#   'cod': 200},
#  {'coord': {'lon': -121.92, 'lat': 36.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 65.44,
#    'feels_like': 63.84,
#    'temp_min': 64,
#    'temp_max': 66.99,
#    'pressure': 1023,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1604519389,
#   'sys': {'type': 1,
#    'id': 4980,
#    'country': 'US',
#    'sunrise': 1604500489,
#    'sunset': 1604538461},
#   'timezone': -28800,
#   'id': 5380437,
#   'name': 'Pacific Grove',
#   'cod': 200},
#  {'coord': {'lon': -65.71, 'lat': 66.15},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 8.6,
#    'feels_like': -5.67,
#    'temp_min': 8.6,
#    'temp_max': 8.6,
#    'pressure': 1009,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 270},
#   'clouds': {'all': 20},
#   'dt': 1604519404,
#   'sys': {'type': 1,
#    'id': 968,
#    'country': 'CA',
#    'sunrise': 1604493111,
#    'sunset': 1604518857},
#   'timezone': -18000,
#   'id': 6096551,
#   'name': 'Pangnirtung',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 79,
#    'feels_like': 75.36,
#    'temp_min': 79,
#    'temp_max': 79,
#    'pressure': 1014,
#    'humidity': 77,
#    'sea_level': 1014,
#    'grnd_level': 1011},
#   'visibility': 10000,
#   'wind': {'speed': 21.05, 'deg': 95},
#   'rain': {'1h': 0.15},
#   'clouds': {'all': 8},
#   'dt': 1604519404,
#   'sys': {'country': 'PF', 'sunrise': 1604501106, 'sunset': 1604546056},
#   'timezone': -34200,
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 75.24,
#    'feels_like': 71.1,
#    'temp_min': 72,
#    'temp_max': 80.6,
#    'pressure': 1013,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1604519404,
#   'sys': {'type': 1,
#    'id': 8521,
#    'country': 'EC',
#    'sunrise': 1604490041,
#    'sunset': 1604533754},
#   'timezone': -21600,
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': 6.61, 'lat': 36.37},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.8,
#    'feels_like': 55.81,
#    'temp_min': 60.8,
#    'temp_max': 60.8,
#    'pressure': 1021,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1604519162,
#   'sys': {'type': 1,
#    'id': 1074,
#    'country': 'DZ',
#    'sunrise': 1604469594,
#    'sunset': 1604507659},
#   'timezone': 3600,
#   'id': 2501152,
#   'name': 'Constantine',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 68.29,
#    'feels_like': 66.27,
#    'temp_min': 68.29,
#    'temp_max': 68.29,
#    'pressure': 1014,
#    'humidity': 85,
#    'sea_level': 1014,
#    'grnd_level': 1012},
#   'visibility': 10000,
#   'wind': {'speed': 11.92, 'deg': 100},
#   'clouds': {'all': 100},
#   'dt': 1604519404,
#   'sys': {'country': 'ZA', 'sunrise': 1604459361, 'sunset': 1604508157},
#   'timezone': 7200,
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': -59.52, 'lat': 13.22},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 86,
#    'feels_like': 85.68,
#    'temp_min': 86,
#    'temp_max': 86,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 100},
#   'clouds': {'all': 20},
#   'dt': 1604519404,
#   'sys': {'type': 1,
#    'id': 8772,
#    'country': 'BB',
#    'sunrise': 1604483586,
#    'sunset': 1604525411},
#   'timezone': -14400,
#   'id': 3374083,
#   'name': 'Bathsheba',
#   'cod': 200},
#  {'coord': {'lon': 91.64, 'lat': 48.01},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 22.82,
#    'feels_like': 16.63,
#    'temp_min': 22.82,
#    'temp_max': 22.82,
#    'pressure': 1029,
#    'humidity': 91,
#    'sea_level': 1029,
#    'grnd_level': 864},
#   'visibility': 10000,
#   'wind': {'speed': 2.21, 'deg': 180},
#   'clouds': {'all': 2},
#   'dt': 1604519404,
#   'sys': {'country': 'MN', 'sunrise': 1604537075, 'sunset': 1604572167},
#   'timezone': 25200,
#   'id': 1516048,
#   'name': 'Khovd',
#   'cod': 200},
#  {'coord': {'lon': 111.97, 'lat': 21.85},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 66.76,
#    'feels_like': 66.79,
#    'temp_min': 66.76,
#    'temp_max': 66.76,
#    'pressure': 1016,
#    'humidity': 78,
#    'sea_level': 1016,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 5.55, 'deg': 25},
#   'clouds': {'all': 93},
#   'dt': 1604519404,
#   'sys': {'country': 'CN', 'sunrise': 1604529473, 'sunset': 1604570011},
#   'timezone': 28800,
#   'id': 1806408,
#   'name': 'Yangjiang',
#   'cod': 200},
#  {'coord': {'lon': 178.42, 'lat': 69.38},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 4.87,
#    'feels_like': -5.93,
#    'temp_min': 4.87,
#    'temp_max': 4.87,
#    'pressure': 1006,
#    'humidity': 80,
#    'sea_level': 1006,
#    'grnd_level': 1005},
#   'visibility': 10000,
#   'wind': {'speed': 7.99, 'deg': 138},
#   'clouds': {'all': 57},
#   'dt': 1604519405,
#   'sys': {'country': 'RU', 'sunrise': 1604522904, 'sunset': 1604544683},
#   'timezone': 43200,
#   'id': 2123814,
#   'name': 'Leningradskiy',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.67},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 29.1,
#    'feels_like': 13.44,
#    'temp_min': 28,
#    'temp_max': 30,
#    'pressure': 1024,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 18.34, 'deg': 320, 'gust': 26.4},
#   'clouds': {'all': 75},
#   'dt': 1604519405,
#   'sys': {'type': 1,
#    'id': 998,
#    'country': 'CA',
#    'sunrise': 1604485218,
#    'sunset': 1604520520},
#   'timezone': -12600,
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 68.7,
#    'feels_like': 61.45,
#    'temp_min': 66.99,
#    'temp_max': 70,
#    'pressure': 1008,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 160},
#   'clouds': {'all': 20},
#   'dt': 1604519179,
#   'sys': {'type': 1,
#    'id': 1899,
#    'country': 'ZA',
#    'sunrise': 1604461359,
#    'sunset': 1604510226},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 119.37, 'lat': -5.32},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 79.99,
#    'feels_like': 85.17,
#    'temp_min': 79.99,
#    'temp_max': 79.99,
#    'pressure': 1009,
#    'humidity': 75,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 5.57, 'deg': 116},
#   'clouds': {'all': 15},
#   'dt': 1604519405,
#   'sys': {'country': 'ID', 'sunrise': 1604525798, 'sunset': 1604570134},
#   'timezone': 28800,
#   'id': 1644605,
#   'name': 'Galesong',
#   'cod': 200},
#  {'coord': {'lon': 31.85, 'lat': -26.03},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 71.31,
#    'feels_like': 67.96,
#    'temp_min': 64.4,
#    'temp_max': 75.2,
#    'pressure': 1014,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 240},
#   'clouds': {'all': 70},
#   'dt': 1604519405,
#   'sys': {'type': 1,
#    'id': 2029,
#    'country': 'SZ',
#    'sunrise': 1604458871,
#    'sunset': 1604506268},
#   'timezone': 7200,
#   'id': 934966,
#   'name': 'Mhlume',
#   'cod': 200},
#  {'coord': {'lon': 103.03, 'lat': 54.17},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 20.07,
#    'feels_like': 12.31,
#    'temp_min': 20.07,
#    'temp_max': 20.07,
#    'pressure': 1020,
#    'humidity': 95,
#    'sea_level': 1020,
#    'grnd_level': 964},
#   'visibility': 10000,
#   'wind': {'speed': 4.72, 'deg': 214},
#   'clouds': {'all': 57},
#   'dt': 1604519405,
#   'sys': {'country': 'RU', 'sunrise': 1604535415, 'sunset': 1604568360},
#   'timezone': 28800,
#   'id': 2013865,
#   'name': "Ust'-Uda",
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -0.81,
#    'feels_like': -8.03,
#    'temp_min': -0.81,
#    'temp_max': -0.81,
#    'pressure': 993,
#    'humidity': 87,
#    'sea_level': 993,
#    'grnd_level': 993},
#   'visibility': 1661,
#   'wind': {'speed': 1.36, 'deg': 21},
#   'clouds': {'all': 99},
#   'dt': 1604519405,
#   'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'timezone': -14400,
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': -27.98, 'lat': 39.05},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 61,
#    'feels_like': 50.81,
#    'temp_min': 61,
#    'temp_max': 61,
#    'pressure': 1035,
#    'humidity': 72,
#    'sea_level': 1035,
#    'grnd_level': 1029},
#   'visibility': 10000,
#   'wind': {'speed': 19.17, 'deg': 49},
#   'clouds': {'all': 28},
#   'dt': 1604519405,
#   'sys': {'country': 'PT', 'sunrise': 1604478183, 'sunset': 1604515674},
#   'timezone': -3600,
#   'id': 3372964,
#   'name': 'Lagoa',
#   'cod': 200},
#  {'coord': {'lon': -17.92, 'lat': 28.66},
#   'weather': [{'id': 302,
#     'main': 'Drizzle',
#     'description': 'heavy intensity drizzle',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 62.96,
#    'feels_like': 59.58,
#    'temp_min': 62.01,
#    'temp_max': 64.4,
#    'pressure': 1018,
#    'humidity': 88},
#   'visibility': 9000,
#   'wind': {'speed': 11.41, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1604519405,
#   'sys': {'type': 1,
#    'id': 2377,
#    'country': 'ES',
#    'sunrise': 1604474772,
#    'sunset': 1604514256},
#   'timezone': 0,
#   'id': 2514651,
#   'name': 'Los Llanos de Aridane',
#   'cod': 200},
#  {'coord': {'lon': 170.31, 'lat': 69.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 2.82,
#    'feels_like': -5.19,
#    'temp_min': 2.82,
#    'temp_max': 2.82,
#    'pressure': 1002,
#    'humidity': 86,
#    'sea_level': 1002,
#    'grnd_level': 997},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 166},
#   'clouds': {'all': 97},
#   'dt': 1604519406,
#   'sys': {'country': 'RU', 'sunrise': 1604525095, 'sunset': 1604546385},
#   'timezone': 43200,
#   'id': 2122090,
#   'name': 'Pevek',
#   'cod': 200},
#  {'coord': {'lon': -74.28, 'lat': 10.99},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 87.01,
#    'feels_like': 97.66,
#    'temp_min': 87.01,
#    'temp_max': 87.01,
#    'pressure': 1007,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 303, 'gust': 1.99},
#   'rain': {'1h': 0.49},
#   'clouds': {'all': 98},
#   'dt': 1604519406,
#   'sys': {'type': 3,
#    'id': 37763,
#    'country': 'CO',
#    'sunrise': 1604486975,
#    'sunset': 1604529107},
#   'timezone': -18000,
#   'id': 3671615,
#   'name': 'Puebloviejo',
#   'cod': 200},
#  {'coord': {'lon': 12.69, 'lat': 67.67},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 42.8,
#    'feels_like': 26.19,
#    'temp_min': 42.8,
#    'temp_max': 42.8,
#    'pressure': 994,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 25.28, 'deg': 240},
#   'rain': {'1h': 1.78},
#   'clouds': {'all': 40},
#   'dt': 1604519406,
#   'sys': {'type': 1,
#    'id': 1661,
#    'country': 'NO',
#    'sunrise': 1604475038,
#    'sunset': 1604499297},
#   'timezone': 3600,
#   'id': 3137469,
#   'name': 'Sørland',
#   'cod': 200},
#  {'coord': {'lon': 39.51, 'lat': 68.05},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 36.61,
#    'feels_like': 20.19,
#    'temp_min': 36.61,
#    'temp_max': 36.61,
#    'pressure': 1002,
#    'humidity': 87,
#    'sea_level': 1002,
#    'grnd_level': 1000},
#   'visibility': 10000,
#   'wind': {'speed': 23.11, 'deg': 220},
#   'clouds': {'all': 88},
#   'dt': 1604519406,
#   'sys': {'country': 'RU', 'sunrise': 1604468803, 'sunset': 1604492658},
#   'timezone': 10800,
#   'id': 556268,
#   'name': 'Ostrovnoy',
#   'cod': 200},
#  {'coord': {'lon': -71.24, 'lat': 8.55},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 73.98,
#    'feels_like': 76.21,
#    'temp_min': 73.98,
#    'temp_max': 73.98,
#    'pressure': 1008,
#    'humidity': 67,
#    'sea_level': 1008,
#    'grnd_level': 882},
#   'visibility': 777,
#   'wind': {'speed': 3.44, 'deg': 262},
#   'rain': {'1h': 1.22},
#   'clouds': {'all': 92},
#   'dt': 1604519406,
#   'sys': {'country': 'VE', 'sunrise': 1604486078, 'sunset': 1604528544},
#   'timezone': -14400,
#   'id': 3644417,
#   'name': 'Ejido',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 44.24,
#    'feels_like': 37.17,
#    'temp_min': 43,
#    'temp_max': 45,
#    'pressure': 1016,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 6.55, 'deg': 260},
#   'clouds': {'all': 20},
#   'dt': 1604519174,
#   'sys': {'type': 1,
#    'id': 9545,
#    'country': 'AU',
#    'sunrise': 1604515733,
#    'sunset': 1604566778},
#   'timezone': 39600,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': -79.24, 'lat': 42.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'feels_like': 52.54,
#    'temp_min': 64.4,
#    'temp_max': 64.4,
#    'pressure': 1024,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 190},
#   'clouds': {'all': 1},
#   'dt': 1604519109,
#   'sys': {'type': 1,
#    'id': 4588,
#    'country': 'US',
#    'sunrise': 1604490846,
#    'sunset': 1604527617},
#   'timezone': -18000,
#   'id': 5122534,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 164.02, 'lat': -20.23},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 75.81,
#    'feels_like': 78.1,
#    'temp_min': 75.81,
#    'temp_max': 75.81,
#    'pressure': 1013,
#    'humidity': 81,
#    'sea_level': 1013,
#    'grnd_level': 1013},
#   'visibility': 10000,
#   'wind': {'speed': 9.08, 'deg': 160},
#   'clouds': {'all': 28},
#   'dt': 1604519407,
#   'sys': {'country': 'NC', 'sunrise': 1604514003, 'sunset': 1604560496},
#   'timezone': 39600,
#   'id': 2138555,
#   'name': 'Poum',
#   'cod': 200},
#  {'coord': {'lon': 71.72, 'lat': 40.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 46.44,
#    'feels_like': 41.07,
#    'temp_min': 46.44,
#    'temp_max': 46.44,
#    'pressure': 1026,
#    'humidity': 45,
#    'sea_level': 1026,
#    'grnd_level': 962},
#   'visibility': 10000,
#   'wind': {'speed': 1.83, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1604519407,
#   'sys': {'country': 'UZ', 'sunrise': 1604540860, 'sunset': 1604577944},
#   'timezone': 18000,
#   'id': 1513491,
#   'name': 'Yangi Marg`ilon',
#   'cod': 200},
#  {'coord': {'lon': 147.92, 'lat': 70.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -14.44,
#    'feels_like': -24.11,
#    'temp_min': -14.44,
#    'temp_max': -14.44,
#    'pressure': 1007,
#    'humidity': 85,
#    'sea_level': 1007,
#    'grnd_level': 1001},
#   'visibility': 10000,
#   'wind': {'speed': 5.06, 'deg': 33},
#   'clouds': {'all': 0},
#   'dt': 1604519407,
#   'sys': {'country': 'RU', 'sunrise': 1604531251, 'sunset': 1604550977},
#   'timezone': 39600,
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': -105.2, 'lat': 20.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.5,
#    'feels_like': 85.51,
#    'temp_min': 84.99,
#    'temp_max': 86,
#    'pressure': 1012,
#    'humidity': 45},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 200},
#   'clouds': {'all': 5},
#   'dt': 1604519407,
#   'sys': {'type': 1,
#    'id': 7156,
#    'country': 'MX',
#    'sunrise': 1604495093,
#    'sunset': 1604535831},
#   'timezone': -21600,
#   'id': 4004293,
#   'name': 'Ixtapa',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.01,
#    'feels_like': 56.5,
#    'temp_min': 60.01,
#    'temp_max': 60.01,
#    'pressure': 1006,
#    'humidity': 89},
#   'visibility': 10000,
#   'wind': {'speed': 10, 'deg': 238, 'gust': 15.01},
#   'clouds': {'all': 92},
#   'dt': 1604519407,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1604510093,
#    'sunset': 1604562083},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 96.13, 'lat': 4.14},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 75.87,
#    'feels_like': 82.4,
#    'temp_min': 75.87,
#    'temp_max': 75.87,
#    'pressure': 1010,
#    'humidity': 88,
#    'sea_level': 1010,
#    'grnd_level': 1010},
#   'visibility': 10000,
#   'wind': {'speed': 3.85, 'deg': 18},
#   'rain': {'1h': 0.562},
#   'clouds': {'all': 100},
#   'dt': 1604519407,
#   'sys': {'country': 'ID', 'sunrise': 1604532017, 'sunset': 1604575071},
#   'timezone': 25200,
#   'id': 1214488,
#   'name': 'Meulaboh',
#   'cod': 200},
#  {'coord': {'lon': 45.34, 'lat': 2.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 79.21,
#    'feels_like': 82.33,
#    'temp_min': 79.21,
#    'temp_max': 79.21,
#    'pressure': 1012,
#    'humidity': 84,
#    'sea_level': 1012,
#    'grnd_level': 1009},
#   'visibility': 10000,
#   'wind': {'speed': 11.77, 'deg': 208},
#   'clouds': {'all': 40},
#   'dt': 1604519108,
#   'sys': {'country': 'SO', 'sunrise': 1604457660, 'sunset': 1604501003},
#   'timezone': 10800,
#   'id': 53654,
#   'name': 'Mogadishu',
#   'cod': 200},
#  {'coord': {'lon': -156.79, 'lat': 71.29},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 26.6,
#    'feels_like': 6.66,
#    'temp_min': 26.6,
#    'temp_max': 26.6,
#    'pressure': 1003,
#    'humidity': 73},
#   'visibility': 6437,
#   'wind': {'speed': 26.4, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1604519408,
#   'sys': {'type': 1,
#    'id': 7649,
#    'country': 'US',
#    'sunrise': 1604518544,
#    'sunset': 1604537144},
#   'timezone': -32400,
#   'id': 5880054,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': -2.55, 'lat': 55.48},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 44.06,
#    'feels_like': 34.99,
#    'temp_min': 43,
#    'temp_max': 45,
#    'pressure': 1036,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 11.9, 'deg': 230},
#   'clouds': {'all': 72},
#   'dt': 1604519408,
#   'sys': {'type': 3,
#    'id': 2007433,
#    'country': 'GB',
#    'sunrise': 1604474541,
#    'sunset': 1604507110},
#   'timezone': 0,
#   'id': 2645970,
#   'name': 'Jedburgh',
#   'cod': 200},
#  {'coord': {'lon': -124.16, 'lat': 40.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 67.46,
#    'feels_like': 66.2,
#    'temp_min': 66,
#    'temp_max': 69.01,
#    'pressure': 1025,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 340},
#   'clouds': {'all': 1},
#   'dt': 1604519408,
#   'sys': {'type': 1,
#    'id': 4127,
#    'country': 'US',
#    'sunrise': 1604501459,
#    'sunset': 1604538566},
#   'timezone': -28800,
#   'id': 5563839,
#   'name': 'Fortuna',
#   'cod': 200},
#  {'coord': {'lon': 105.97, 'lat': 10.25},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'feels_like': 87.93,
#    'temp_min': 77,
#    'temp_max': 77,
#    'pressure': 1009,
#    'humidity': 100},
#   'visibility': 10000,
#   'wind': {'speed': 1.12, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1604519408,
#   'sys': {'type': 1,
#    'id': 9305,
#    'country': 'VN',
#    'sunrise': 1604530072,
#    'sunset': 1604572292},
#   'timezone': 25200,
#   'id': 1562693,
#   'name': 'Vinh Long',
#   'cod': 200},
#  {'coord': {'lon': -48.5, 'lat': -27.61},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 67.28,
#    'feels_like': 57.72,
#    'temp_min': 66,
#    'temp_max': 69.01,
#    'pressure': 1018,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 18.34, 'deg': 190, 'gust': 32.21},
#   'clouds': {'all': 75},
#   'dt': 1604519118,
#   'sys': {'type': 1,
#    'id': 8360,
#    'country': 'BR',
#    'sunrise': 1604478009,
#    'sunset': 1604525698},
#   'timezone': -10800,
#   'id': 6323121,
#   'name': 'Florianópolis',
#   'cod': 200},
#  {'coord': {'lon': 105.77, 'lat': 19.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 66.65,
#    'feels_like': 68,
#    'temp_min': 66.65,
#    'temp_max': 66.65,
#    'pressure': 1015,
#    'humidity': 81,
#    'sea_level': 1015,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 3.85, 'deg': 303},
#   'clouds': {'all': 47},
#   'dt': 1604519408,
#   'sys': {'country': 'VN', 'sunrise': 1604530805, 'sunset': 1604571655},
#   'timezone': 25200,
#   'id': 1566166,
#   'name': 'Thanh Hoa',
#   'cod': 200},
#  {'coord': {'lon': 145.92, 'lat': -41.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 44.01,
#    'feels_like': 31.12,
#    'temp_min': 44.01,
#    'temp_max': 44.01,
#    'pressure': 1008,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 17, 'deg': 173, 'gust': 25.01},
#   'clouds': {'all': 0},
#   'dt': 1604519408,
#   'sys': {'type': 3,
#    'id': 2018289,
#    'country': 'AU',
#    'sunrise': 1604516309,
#    'sunset': 1604566879},
#   'timezone': 39600,
#   'id': 2173125,
#   'name': 'Burnie',
#   'cod': 200},
#  {'coord': {'lon': -8.03, 'lat': 13.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 83.23,
#    'feels_like': 77.95,
#    'temp_min': 83.23,
#    'temp_max': 83.23,
#    'pressure': 1011,
#    'humidity': 23,
#    'sea_level': 1011,
#    'grnd_level': 966},
#   'visibility': 10000,
#   'wind': {'speed': 5.97, 'deg': 102},
#   'clouds': {'all': 0},
#   'dt': 1604519408,
#   'sys': {'country': 'ML', 'sunrise': 1604471250, 'sunset': 1604513031},
#   'timezone': 0,
#   'id': 2454955,
#   'name': 'Kolokani',
#   'cod': 200},
#  {'coord': {'lon': -15.12, 'lat': 15.4},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 90.1,
#    'feels_like': 84.52,
#    'temp_min': 90.1,
#    'temp_max': 90.1,
#    'pressure': 1009,
#    'humidity': 20,
#    'sea_level': 1009,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 7.27, 'deg': 171},
#   'clouds': {'all': 0},
#   'dt': 1604519408,
#   'sys': {'country': 'SN', 'sunrise': 1604473080, 'sunset': 1604514604},
#   'timezone': 0,
#   'id': 2249281,
#   'name': 'Linguère',
#   'cod': 200},
#  {'coord': {'lon': 108.01, 'lat': 61.28},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 14.97,
#    'feels_like': 6.89,
#    'temp_min': 14.97,
#    'temp_max': 14.97,
#    'pressure': 1006,
#    'humidity': 96,
#    'sea_level': 1006,
#    'grnd_level': 972},
#   'visibility': 723,
#   'wind': {'speed': 4.59, 'deg': 239},
#   'clouds': {'all': 100},
#   'dt': 1604519409,
#   'sys': {'country': 'RU', 'sunrise': 1604536016, 'sunset': 1604565369},
#   'timezone': 28800,
#   'id': 2012956,
#   'name': 'Yerbogachën',
#   'cod': 200},
#  {'coord': {'lon': 19.23, 'lat': -34.42},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 68,
#    'feels_like': 67.8,
#    'temp_min': 68,
#    'temp_max': 68,
#    'pressure': 1013,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 131, 'gust': 14},
#   'clouds': {'all': 79},
#   'dt': 1604519409,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'country': 'ZA',
#    'sunrise': 1604461114,
#    'sunset': 1604510082},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': -120.46, 'lat': 34.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.47,
#    'feels_like': 68.02,
#    'temp_min': 68,
#    'temp_max': 75.2,
#    'pressure': 1020,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1604519256,
#   'sys': {'type': 1,
#    'id': 4747,
#    'country': 'US',
#    'sunrise': 1604499940,
#    'sunset': 1604538309},
#   'timezone': -28800,
#   'id': 5367788,
#   'name': 'Lompoc',
#   'cod': 200},
#  {'coord': {'lon': 80.55, 'lat': 73.51},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 1.38,
#    'feels_like': -9.13,
#    'temp_min': 1.38,
#    'temp_max': 1.38,
#    'pressure': 1012,
#    'humidity': 92,
#    'sea_level': 1012,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 7.45, 'deg': 86},
#   'clouds': {'all': 0},
#   'dt': 1604519409,
#   'sys': {'country': 'RU', 'sunrise': 1604551064, 'sunset': 1604563502},
#   'timezone': 25200,
#   'id': 1507390,
#   'name': 'Dikson',
#   'cod': 200},
#  {'coord': {'lon': -42.03, 'lat': -22.97},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'feels_like': 77,
#    'temp_min': 75.2,
#    'temp_max': 75.2,
#    'pressure': 1014,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1604519409,
#   'sys': {'type': 1,
#    'id': 8326,
#    'country': 'BR',
#    'sunrise': 1604476849,
#    'sunset': 1604523752},
#   'timezone': -10800,
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': -73.82, 'lat': -41.87},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 54.72,
#    'feels_like': 44.73,
#    'temp_min': 51.8,
#    'temp_max': 57.99,
#    'pressure': 1013,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 18.34, 'deg': 310},
#   'clouds': {'all': 75},
#   'dt': 1604519312,
#   'sys': {'type': 1,
#    'id': 8512,
#    'country': 'CL',
#    'sunrise': 1604482571,
#    'sunset': 1604533290},
#   'timezone': -10800,
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': 123.35, 'lat': 7.43},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.53,
#    'feels_like': 84.45,
#    'temp_min': 78.53,
#    'temp_max': 78.53,
#    'pressure': 1011,
#    'humidity': 82,
#    'sea_level': 1011,
#    'grnd_level': 998},
#   'visibility': 10000,
#   'wind': {'speed': 5.41, 'deg': 87},
#   'clouds': {'all': 100},
#   'dt': 1604519409,
#   'sys': {'country': 'PH', 'sunrise': 1604525706, 'sunset': 1604568315},
#   'timezone': 28800,
#   'id': 1958647,
#   'name': 'Panubigan',
#   'cod': 200},
#  {'coord': {'lon': -73.36, 'lat': 41.14},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 59.95,
#    'feels_like': 55.13,
#    'temp_min': 57.99,
#    'temp_max': 61,
#    'pressure': 1030,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1604519410,
#   'sys': {'type': 1,
#    'id': 3409,
#    'country': 'US',
#    'sunrise': 1604489319,
#    'sunset': 1604526321},
#   'timezone': -18000,
#   'id': 4845585,
#   'name': 'Westport',
#   'cod': 200},
#  {'coord': {'lon': -72.42, 'lat': -35.33},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 58.95,
#    'feels_like': 45.03,
#    'temp_min': 58.95,
#    'temp_max': 58.95,
#    'pressure': 1021,
#    'humidity': 57,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 22.12, 'deg': 216},
#   'clouds': {'all': 59},
#   'dt': 1604519410,
#   'sys': {'country': 'CL', 'sunrise': 1604483001, 'sunset': 1604532188},
#   'timezone': -10800,
#   'id': 3893726,
#   'name': 'Constitución',
#   'cod': 200},
#  {'coord': {'lon': 72.64, 'lat': 10.57},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 82.51,
#    'feels_like': 88.45,
#    'temp_min': 82.51,
#    'temp_max': 82.51,
#    'pressure': 1009,
#    'humidity': 76,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 6.98, 'deg': 277},
#   'rain': {'1h': 0.16},
#   'clouds': {'all': 77},
#   'dt': 1604519410,
#   'sys': {'country': 'IN', 'sunrise': 1604538095, 'sunset': 1604580268},
#   'timezone': 19800,
#   'id': 1267390,
#   'name': 'Kavaratti',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 66.2,
#    'feels_like': 64.67,
#    'temp_min': 66.2,
#    'temp_max': 66.2,
#    'pressure': 1014,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 170},
#   'rain': {'1h': 0.21},
#   'clouds': {'all': 69},
#   'dt': 1604519410,
#   'sys': {'type': 1,
#    'id': 1966,
#    'country': 'ZA',
#    'sunrise': 1604460909,
#    'sunset': 1604509898},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': -51.99, 'lat': -6.64},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 81.27,
#    'feels_like': 90.36,
#    'temp_min': 81.27,
#    'temp_max': 81.27,
#    'pressure': 1007,
#    'humidity': 85,
#    'sea_level': 1007,
#    'grnd_level': 984},
#   'visibility': 7476,
#   'wind': {'speed': 3.65, 'deg': 264},
#   'rain': {'1h': 2.3},
#   'clouds': {'all': 100},
#   'dt': 1604519410,
#   'sys': {'country': 'BR', 'sunrise': 1604480437, 'sunset': 1604524945},
#   'timezone': -10800,
#   'id': 3388847,
#   'name': 'São Félix do Xingu',
#   'cod': 200},
#  {'coord': {'lon': 55.99, 'lat': 30.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 52.25,
#    'feels_like': 46.76,
#    'temp_min': 52.25,
#    'temp_max': 52.25,
#    'pressure': 1018,
#    'humidity': 40,
#    'sea_level': 1018,
#    'grnd_level': 852},
#   'visibility': 10000,
#   'wind': {'speed': 2.59, 'deg': 242},
#   'clouds': {'all': 0},
#   'dt': 1604519410,
#   'sys': {'country': 'IR', 'sunrise': 1604457175, 'sunset': 1604496375},
#   'timezone': 12600,
#   'id': 118994,
#   'name': 'Rafsanjān',
#   'cod': 200},
#  {'coord': {'lon': 27.02, 'lat': 39.6},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'feels_like': 50.49,
#    'temp_min': 59,
#    'temp_max': 59,
#    'pressure': 1022,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 70},
#   'clouds': {'all': 40},
#   'dt': 1604519410,
#   'sys': {'type': 1,
#    'id': 7015,
#    'country': 'TR',
#    'sunrise': 1604465034,
#    'sunset': 1604502423},
#   'timezone': 10800,
#   'id': 315985,
#   'name': 'Edremit',
#   'cod': 200},
#  {'coord': {'lon': 54.09, 'lat': 17.02},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'feels_like': 78.04,
#    'temp_min': 75.2,
#    'temp_max': 75.2,
#    'pressure': 1013,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 330},
#   'clouds': {'all': 0},
#   'dt': 1604519410,
#   'sys': {'type': 1,
#    'id': 7562,
#    'country': 'OM',
#    'sunrise': 1604456580,
#    'sunset': 1604497882},
#   'timezone': 14400,
#   'id': 286621,
#   'name': 'Salalah',
#   'cod': 200},
#  {'coord': {'lon': 8.83, 'lat': 63.73},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'},
#    {'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 44.6,
#    'feels_like': 26.31,
#    'temp_min': 44.6,
#    'temp_max': 44.6,
#    'pressure': 1009,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 28.86, 'deg': 260},
#   'rain': {'1h': 0.87},
#   'clouds': {'all': 75},
#   'dt': 1604519410,
#   'sys': {'type': 1,
#    'id': 1647,
#    'country': 'NO',
#    'sunrise': 1604474143,
#    'sunset': 1604502045},
#   'timezone': 3600,
#   'id': 3139597,
# ...
#    'humidity': 97,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 1.59, 'deg': 45},
#   'clouds': {'all': 36},
#   'dt': 1604519492,
#   'sys': {'country': 'ID', 'sunrise': 1604526984, 'sunset': 1604570926},
#   'timezone': 28800,
#   'id': 1651461,
#   'name': 'Amuntai',
#   'cod': 200},
#  {'coord': {'lon': 152.15, 'lat': -32.72},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 301, 'main': 'Drizzle', 'description': 'drizzle', 'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 64.17,
#    'feels_like': 64.27,
#    'temp_min': 64,
#    'temp_max': 64.4,
#    'pressure': 1006,
#    'humidity': 82},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 140},
#   'rain': {'1h': 0.16},
#   'clouds': {'all': 90},
#   'dt': 1604519492,
#   'sys': {'type': 1,
#    'id': 9605,
#    'country': 'AU',
#    'sunrise': 1604515753,
#    'sunset': 1604564444},
#   'timezone': 39600,
#   'id': 2155562,
#   'name': 'Nelson Bay',
#   'cod': 200},
#  {'coord': {'lon': 7.07, 'lat': 6.11},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 74.23,
#    'feels_like': 78.66,
#    'temp_min': 74.23,
#    'temp_max': 74.23,
#    'pressure': 1012,
#    'humidity': 92,
#    'sea_level': 1012,
#    'grnd_level': 996},
#   'visibility': 10000,
#   'wind': {'speed': 7.31, 'deg': 160},
#   'rain': {'1h': 1.67},
#   'clouds': {'all': 100},
#   'dt': 1604519492,
#   'sys': {'country': 'NG', 'sunrise': 1604467117, 'sunset': 1604509916},
#   'timezone': 3600,
#   'id': 2351740,
#   'name': 'Agulu',
#   'cod': 200},
#  {'coord': {'lon': 6.13, 'lat': 62.58},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 44.26,
#    'feels_like': 29.19,
#    'temp_min': 42.01,
#    'temp_max': 46,
#    'pressure': 1013,
#    'humidity': 87},
#   'visibility': 4900,
#   'wind': {'speed': 23.04, 'deg': 210},
#   'rain': {'1h': 0.44},
#   'clouds': {'all': 75},
#   'dt': 1604519492,
#   'sys': {'type': 1,
#    'id': 1602,
#    'country': 'NO',
#    'sunrise': 1604474375,
#    'sunset': 1604503109},
#   'timezone': 3600,
#   'id': 3141667,
#   'name': 'Roald',
#   'cod': 200},
#  {'coord': {'lon': -119.61, 'lat': 36.57},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 72.72,
#    'feels_like': 68.86,
#    'temp_min': 71.6,
#    'temp_max': 73.4,
#    'pressure': 1023,
#    'humidity': 35},
#   'visibility': 9656,
#   'wind': {'speed': 4.16, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1604519492,
#   'sys': {'type': 1,
#    'id': 5145,
#    'country': 'US',
#    'sunrise': 1604499929,
#    'sunset': 1604537912},
#   'timezone': -28800,
#   'id': 5394329,
#   'name': 'Selma',
#   'cod': 200},
#  {'coord': {'lon': 53.15, 'lat': 67.68},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 33.6,
#    'feels_like': 23.47,
#    'temp_min': 33.6,
#    'temp_max': 33.6,
#    'pressure': 1007,
#    'humidity': 94,
#    'sea_level': 1007,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 11.68, 'deg': 243},
#   'clouds': {'all': 31},
#   'dt': 1604519492,
#   'sys': {'country': 'RU', 'sunrise': 1604465306, 'sunset': 1604489608},
#   'timezone': 10800,
#   'id': 866062,
#   'name': 'Iskateley',
#   'cod': 200},
#  {'coord': {'lon': 37.38, 'lat': 55.7},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 45.81,
#    'feels_like': 38.98,
#    'temp_min': 45,
#    'temp_max': 46.4,
#    'pressure': 1026,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 200},
#   'clouds': {'all': 75},
#   'dt': 1604519492,
#   'sys': {'type': 1,
#    'id': 9033,
#    'country': 'RU',
#    'sunrise': 1604464991,
#    'sunset': 1604497493},
#   'timezone': 10800,
#   'id': 529368,
#   'name': 'Marfino',
#   'cod': 200},
#  {'coord': {'lon': 111.89, 'lat': -8.12},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 76.59,
#    'feels_like': 84.33,
#    'temp_min': 76.59,
#    'temp_max': 76.59,
#    'pressure': 1010,
#    'humidity': 87,
#    'sea_level': 1010,
#    'grnd_level': 999},
#   'visibility': 10000,
#   'wind': {'speed': 2.06, 'deg': 247},
#   'rain': {'1h': 0.32820000000000005},
#   'clouds': {'all': 57},
#   'dt': 1604519493,
#   'sys': {'country': 'ID', 'sunrise': 1604527399, 'sunset': 1604572123},
#   'timezone': 25200,
#   'id': 1648082,
#   'name': 'Boyolangu',
#   'cod': 200},
#  {'coord': {'lon': 5.11, 'lat': 61.94},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 45.45,
#    'feels_like': 28.35,
#    'temp_min': 42.8,
#    'temp_max': 48.2,
#    'pressure': 1018,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 26.4, 'deg': 220},
#   'rain': {'1h': 0.51},
#   'clouds': {'all': 75},
#   'dt': 1604519493,
#   'sys': {'type': 1,
#    'id': 1616,
#    'country': 'NO',
#    'sunrise': 1604474405,
#    'sunset': 1604503569},
#   'timezone': 3600,
#   'id': 3146487,
#   'name': 'Måløy',
#   'cod': 200},
#  {'coord': {'lon': 9.1, 'lat': 61.88},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 32.67,
#    'feels_like': 25.52,
#    'temp_min': 32.67,
#    'temp_max': 32.67,
#    'pressure': 1017,
#    'humidity': 88,
#    'sea_level': 1017,
#    'grnd_level': 966},
#   'visibility': 10000,
#   'wind': {'speed': 5.73, 'deg': 259},
#   'clouds': {'all': 84},
#   'dt': 1604519493,
#   'sys': {'country': 'NO', 'sunrise': 1604473426, 'sunset': 1604502633},
#   'timezone': 3600,
#   'id': 3133053,
#   'name': 'Vågåmo',
#   'cod': 200},
#  {'coord': {'lon': -1.64, 'lat': 41.35},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 45.32,
#    'feels_like': 36,
#    'temp_min': 39.99,
#    'temp_max': 50,
#    'pressure': 1022,
#    'humidity': 93},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 20},
#   'clouds': {'all': 90},
#   'dt': 1604519493,
#   'sys': {'type': 1,
#    'id': 6401,
#    'country': 'ES',
#    'sunrise': 1604472117,
#    'sunset': 1604509097},
#   'timezone': 3600,
#   'id': 3127047,
#   'name': 'Calatayud',
#   'cod': 200},
#  {'coord': {'lon': 116.16, 'lat': 5.34},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 75.09,
#    'feels_like': 81.81,
#    'temp_min': 75,
#    'temp_max': 75.2,
#    'pressure': 1010,
#    'humidity': 94},
#   'visibility': 9000,
#   'wind': {'speed': 4.7, 'deg': 110},
#   'clouds': {'all': 40},
#   'dt': 1604519493,
#   'sys': {'type': 1,
#    'id': 9371,
#    'country': 'MY',
#    'sunrise': 1604527290,
#    'sunset': 1604570183},
#   'timezone': 28800,
#   'id': 1734098,
#   'name': 'Keningau',
#   'cod': 200},
#  {'coord': {'lon': 45.01, 'lat': 10.44},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 78.73,
#    'feels_like': 82.22,
#    'temp_min': 78.73,
#    'temp_max': 78.73,
#    'pressure': 1014,
#    'humidity': 60,
#    'sea_level': 1014,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 2.17, 'deg': 35},
#   'clouds': {'all': 0},
#   'dt': 1604519493,
#   'sys': {'country': 'SO', 'sunrise': 1604458302, 'sunset': 1604500519},
#   'timezone': 10800,
#   'id': 64435,
#   'name': 'Berbera',
#   'cod': 200},
#  {'coord': {'lon': -8.33, 'lat': 40.16},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 54.61,
#    'feels_like': 47.77,
#    'temp_min': 52,
#    'temp_max': 57,
#    'pressure': 1012,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 11.01, 'deg': 90, 'gust': 21},
#   'clouds': {'all': 100},
#   'dt': 1604519493,
#   'sys': {'type': 3,
#    'id': 2001739,
#    'country': 'PT',
#    'sunrise': 1604473587,
#    'sunset': 1604510838},
#   'timezone': 0,
#   'id': 2738381,
#   'name': 'Lata',
#   'cod': 200},
#  {'coord': {'lon': 109.51, 'lat': -7.61},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 59.67,
#    'feels_like': 60.12,
#    'temp_min': 51.01,
#    'temp_max': 64.99,
#    'pressure': 889,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 2.21, 'deg': 314},
#   'rain': {'1h': 0.4},
#   'clouds': {'all': 44},
#   'dt': 1604519493,
#   'sys': {'type': 3,
#    'id': 2034901,
#    'country': 'ID',
#    'sunrise': 1604528006,
#    'sunset': 1604572659},
#   'timezone': 25200,
#   'id': 1643920,
#   'name': 'Gombong',
#   'cod': 200},
#  {'coord': {'lon': 70.58, 'lat': 21.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 75.72,
#    'feels_like': 72.68,
#    'temp_min': 75.72,
#    'temp_max': 75.72,
#    'pressure': 1012,
#    'humidity': 38,
#    'sea_level': 1012,
#    'grnd_level': 1000},
#   'visibility': 10000,
#   'wind': {'speed': 4.76, 'deg': 11},
#   'clouds': {'all': 0},
#   'dt': 1604519494,
#   'sys': {'country': 'IN', 'sunrise': 1604539399, 'sunset': 1604579953},
#   'timezone': 19800,
#   'id': 1269070,
#   'name': 'Jetalsar',
#   'cod': 200},
#  {'coord': {'lon': -6.46, 'lat': 52.33},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 44.42,
#    'feels_like': 40.41,
#    'temp_min': 41,
#    'temp_max': 46.99,
#    'pressure': 1040,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 10},
#   'clouds': {'all': 40},
#   'dt': 1604519287,
#   'sys': {'type': 1,
#    'id': 1556,
#    'country': 'IE',
#    'sunrise': 1604474861,
#    'sunset': 1604508667},
#   'timezone': 0,
#   'id': 2960964,
#   'name': 'Wexford',
#   'cod': 200},
#  {'coord': {'lon': 39.87, 'lat': 47.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'feels_like': 40.77,
#    'temp_min': 50,
#    'temp_max': 50,
#    'pressure': 1024,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 13.42, 'deg': 50},
#   'clouds': {'all': 0},
#   'dt': 1604519494,
#   'sys': {'type': 1,
#    'id': 8971,
#    'country': 'RU',
#    'sunrise': 1604462910,
#    'sunset': 1604498378},
#   'timezone': 10800,
#   'id': 583673,
#   'name': 'Aksay',
#   'cod': 200},
#  {'coord': {'lon': 26.72, 'lat': -22.38},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 73.81,
#    'feels_like': 71.64,
#    'temp_min': 73.81,
#    'temp_max': 73.81,
#    'pressure': 1011,
#    'humidity': 64,
#    'sea_level': 1011,
#    'grnd_level': 890},
#   'visibility': 10000,
#   'wind': {'speed': 10.25, 'deg': 47},
#   'clouds': {'all': 41},
#   'dt': 1604519494,
#   'sys': {'country': 'BW', 'sunrise': 1604460403, 'sunset': 1604507198},
#   'timezone': 7200,
#   'id': 933088,
#   'name': 'Serowe',
#   'cod': 200},
#  {'coord': {'lon': 46.47, 'lat': 14.4},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.71,
#    'feels_like': 56.21,
#    'temp_min': 60.71,
#    'temp_max': 60.71,
#    'pressure': 1016,
#    'humidity': 31,
#    'sea_level': 1016,
#    'grnd_level': 888},
#   'visibility': 10000,
#   'wind': {'speed': 1.12, 'deg': 235},
#   'clouds': {'all': 0},
#   'dt': 1604519494,
#   'sys': {'country': 'YE', 'sunrise': 1604458224, 'sunset': 1604499896},
#   'timezone': 10800,
#   'id': 72181,
#   'name': 'Marzuq',
#   'cod': 200},
#  {'coord': {'lon': 81.98, 'lat': 25.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 66.2,
#    'feels_like': 61.77,
#    'temp_min': 66.2,
#    'temp_max': 66.2,
#    'pressure': 1012,
#    'humidity': 31,
#    'sea_level': 1012,
#    'grnd_level': 1001},
#   'visibility': 10000,
#   'wind': {'speed': 2.26, 'deg': 26},
#   'clouds': {'all': 0},
#   'dt': 1604519494,
#   'sys': {'country': 'IN', 'sunrise': 1604536999, 'sunset': 1604576881},
#   'timezone': 19800,
#   'id': 1276574,
#   'name': 'Bela',
#   'cod': 200},
#  {'coord': {'lon': 116.85, 'lat': -20.74},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 72.84,
#    'feels_like': 68.41,
#    'temp_min': 72.84,
#    'temp_max': 72.84,
#    'pressure': 1012,
#    'humidity': 44,
#    'sea_level': 1012,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 7.83, 'deg': 217},
#   'rain': {'1h': 0.133},
#   'clouds': {'all': 0},
#   'dt': 1604519494,
#   'sys': {'country': 'AU', 'sunrise': 1604525280, 'sunset': 1604571862},
#   'timezone': 28800,
#   'id': 6620339,
#   'name': 'Karratha',
#   'cod': 200},
#  {'coord': {'lon': 42.35, 'lat': 58.38},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 43.61,
#    'feels_like': 36.93,
#    'temp_min': 43.61,
#    'temp_max': 43.61,
#    'pressure': 1023,
#    'humidity': 91,
#    'sea_level': 1023,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 8.32, 'deg': 211},
#   'clouds': {'all': 100},
#   'dt': 1604519495,
#   'sys': {'country': 'RU', 'sunrise': 1604464424, 'sunset': 1604495674},
#   'timezone': 10800,
#   'id': 562161,
#   'name': 'Galich',
#   'cod': 200},
#  {'coord': {'lon': -1.07, 'lat': 11.66},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 83.86,
#    'feels_like': 82.17,
#    'temp_min': 83.86,
#    'temp_max': 83.86,
#    'pressure': 1010,
#    'humidity': 30,
#    'sea_level': 1010,
#    'grnd_level': 979},
#   'visibility': 10000,
#   'wind': {'speed': 2.71, 'deg': 66},
#   'clouds': {'all': 20},
#   'dt': 1604519495,
#   'sys': {'country': 'BF', 'sunrise': 1604469447, 'sunset': 1604511493},
#   'timezone': 0,
#   'id': 2358100,
#   'name': 'Manga',
#   'cod': 200},
#  {'coord': {'lon': 104.97, 'lat': -5.36},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.28,
#    'feels_like': 81.32,
#    'temp_min': 74.28,
#    'temp_max': 74.28,
#    'pressure': 1010,
#    'humidity': 91,
#    'sea_level': 1010,
#    'grnd_level': 998},
#   'visibility': 10000,
#   'wind': {'speed': 2.42, 'deg': 214},
#   'clouds': {'all': 100},
#   'dt': 1604519495,
#   'sys': {'country': 'ID', 'sunrise': 1604529251, 'sunset': 1604573593},
#   'timezone': 25200,
#   'id': 1630639,
#   'name': 'Pringsewu',
#   'cod': 200},
#  {'coord': {'lon': 105.92, 'lat': 49.49},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 28.4,
#    'feels_like': 21.09,
#    'temp_min': 28.4,
#    'temp_max': 28.4,
#    'pressure': 1016,
#    'humidity': 97,
#    'sea_level': 1016,
#    'grnd_level': 933},
#   'visibility': 121,
#   'wind': {'speed': 5.59, 'deg': 347},
#   'clouds': {'all': 100},
#   'dt': 1604519495,
#   'sys': {'country': 'MN', 'sunrise': 1604533876, 'sunset': 1604568512},
#   'timezone': 28800,
#   'id': 2031964,
#   'name': 'Darhan',
#   'cod': 200},
#  {'coord': {'lon': 42.77, 'lat': 51.32},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 39,
#    'feels_like': 32.59,
#    'temp_min': 39,
#    'temp_max': 39,
#    'pressure': 1026,
#    'humidity': 95},
#   'visibility': 10000,
#   'wind': {'speed': 6.67, 'deg': 27},
#   'clouds': {'all': 75},
#   'dt': 1604519495,
#   'sys': {'type': 3,
#    'id': 2021293,
#    'country': 'RU',
#    'sunrise': 1604462852,
#    'sunset': 1604497044},
#   'timezone': 10800,
#   'id': 553766,
#   'name': 'Kamenka',
#   'cod': 200}]

# %%
weather_response
# Out:
# {'coord': {'lon': 42.77, 'lat': 51.32},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 39,
#   'feels_like': 32.59,
#   'temp_min': 39,
#   'temp_max': 39,
#   'pressure': 1026,
#   'humidity': 95},
#  'visibility': 10000,
#  'wind': {'speed': 6.67, 'deg': 27},
#  'clouds': {'all': 75},
#  'dt': 1604519495,
#  'sys': {'type': 3,
#   'id': 2021293,
#   'country': 'RU',
#   'sunrise': 1604462852,
#   'sunset': 1604497044},
#  'timezone': 10800,
#  'id': 553766,
#  'name': 'Kamenka',
#  'cod': 200}

# %%
# create list hold info:
lat_data =  [data.get("coord").get("lat") for data in random_search_data]
lng_data = [data.get("coord").get("lon") for data in random_search_data]
temp_max_data = [data.get("main").get("temp_max") for data in random_search_data]
humid_data = [data.get("main").get("humidity") for data in random_search_data]
cloud_data =[data.get("clouds").get("all") for data in random_search_data]
wind_data = [data.get("wind").get("speed") for data in random_search_data]
id_data = [data.get("id") for data in random_search_data]

# %%
#create a dictionart to hold lists
weather_data = pd.DataFrame({"city name":city_list,
                            "country":country_list,
                            "latitude_deg":lat_data,
                            "longitude_deg":lng_data,
                            "temp_max_F":temp_max_data,
                            "humidity_%":humid_data,
                            "cloudiness_%":cloud_data,
                            "winds speed_mph":wind_data,
                            "city id":id_data})

# %%
city_data_weather_info = weather_data[["city name","country","city id","latitude_deg","longitude_deg","temp_max_F","humidity_%","cloudiness_%","winds speed_mph"]]
city_data_weather_info.head()
# Out:
#         city name country  city id  latitude_deg  longitude_deg  temp_max_F  \
# 0     Yellowknife      CA  6185377         62.46        -114.35        1.99
# 1  Cabo San Lucas      MX  3985710         22.89        -109.91       89.01
# 2         Ushuaia      AR  3833367        -54.80         -68.30       64.40
# 3            Hilo      US  5855927         19.73        -155.09       80.60
# 4           Marti      CU  3547519         22.95         -80.92       77.00
#
#    humidity_%  cloudiness_%  winds speed_mph
# 0          84            75             3.36
# 1          58             5             3.36
# 2          36             0             5.82
# 3          74            90             5.82
# 4          94            75            17.22

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Output File (CSV)

city_data_weather_info.to_csv(output_data_file)
output_data_file = "output_data/output_weather_data_file.csv"

# %%
#show dataframe
city_data_weather_info
# Out:
#           city name country  city id  latitude_deg  longitude_deg  temp_max_F  \
# 0       Yellowknife      CA  6185377         62.46        -114.35        1.99
# 1    Cabo San Lucas      MX  3985710         22.89        -109.91       89.01
# 2           Ushuaia      AR  3833367        -54.80         -68.30       64.40
# 3              Hilo      US  5855927         19.73        -155.09       80.60
# 4             Marti      CU  3547519         22.95         -80.92       77.00
# ..              ...     ...      ...           ...            ...         ...
# 558          Galich      RU   562161         58.38          42.35       43.61
# 559           Manga      BF  2358100         11.66          -1.07       83.86
# 560       Pringsewu      ID  1630639         -5.36         104.97       74.28
# 561          Darhan      MN  2031964         49.49         105.92       28.40
# 562         Kamenka      RU   553766         51.32          42.77       39.00
#
#      humidity_%  cloudiness_%  winds speed_mph
# 0            84            75             3.36
# 1            58             5             3.36
# 2            36             0             5.82
# 3            74            90             5.82
# 4            94            75            17.22
# ..          ...           ...              ...
# 558          91           100             8.32
# 559          30            20             2.71
# 560          91           100             2.42
# 561          97           100             5.59
# 562          95            75             6.67
#
# [563 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_more_than_100 = city_data_weather_info.loc[city_data_weather_info["humidity_%"] > 0,:]
humidity_more_than_100.count()
# Out:
# city name          563
# country            563
# city id            563
# latitude_deg       563
# longitude_deg      563
# temp_max_F         563
# humidity_%         563
# cloudiness_%       563
# winds speed_mph    563
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_weather_info["latitude_deg"],city_data_weather_info["temp_max_F"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Max Temperature (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/Lat_MaxTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_weather_info["latitude_deg"],city_data_weather_info["humidity_%"],edgecolors="black",facecolors="red")
plt.title("City Latitude vs. Humidity  (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/Lat_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_weather_info["latitude_deg"],city_data_weather_info["cloudiness_%"],edgecolors="black",facecolors="green")
plt.title("City Latitude vs. Percent Cloudiness  (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/Lat_Cloundiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_weather_info["latitude_deg"],city_data_weather_info["winds speed_mph"],edgecolors="black",facecolors="orange")
plt.title("City Latitude vs. winds speed (mph  (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("winds speed (mph")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/Lat_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#create northen hemisphere data frame
northern_only = city_data_weather_info.loc[city_data_weather_info["latitude_deg"] > 0,:]
northern_only.head()
# Out:
#          city name country  city id  latitude_deg  longitude_deg  temp_max_F  \
# 0      Yellowknife      CA  6185377         62.46        -114.35        1.99
# 1   Cabo San Lucas      MX  3985710         22.89        -109.91       89.01
# 3             Hilo      US  5855927         19.73        -155.09       80.60
# 4            Marti      CU  3547519         22.95         -80.92       77.00
# 10           Kapaa      US  5848280         22.08        -159.32       82.99
#
#     humidity_%  cloudiness_%  winds speed_mph
# 0           84            75             3.36
# 1           58             5             3.36
# 3           74            90             5.82
# 4           94            75            17.22
# 10          88            75            11.45

# %%
#create southern hemisphere dataframe
southern_only = city_data_weather_info.loc[city_data_weather_info["latitude_deg"] <= 0,:]
southern_only.head()
# Out:
#     city name country  city id  latitude_deg  longitude_deg  temp_max_F  \
# 2     Ushuaia      AR  3833367        -54.80         -68.30       64.40
# 5     Rikitea      PF  4030556        -23.12        -134.97       73.44
# 6        Lebu      CL  3883457        -37.62         -73.65       55.45
# 7  Codrington      AU  2171099        -38.27         141.97       48.42
# 8     Ahipara      NZ  2194098        -35.17         173.17       62.13
#
#    humidity_%  cloudiness_%  winds speed_mph
# 2          36             0             5.82
# 5          75             0            15.28
# 6          63             0            10.74
# 7          73            45            12.73
# 8          93           100            14.54

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_only["latitude_deg"], northern_only["temp_max_F"])
regress_values = northern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_only["latitude_deg"],northern_only["temp_max_F"],edgecolors="black",facecolors="blue")

plt.plot(northern_only["latitude_deg"],regress_values,"r-")

plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.title("Northern Hemisphere City vs. Max Temperature (11/03/2020)")
plt.xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_only["latitude_deg"], southern_only["temp_max_F"])
regress_values = southern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_only["latitude_deg"],southern_only["temp_max_F"],edgecolors="black",facecolors="yellow")

plt.plot(southern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(-53,90),fontsize=15,color="red")

plt.title("Southern Hemisphere City vs. Max Temperature (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/SLat_MaxTemp_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.4159581226882955

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_only["latitude_deg"], northern_only["humidity_%"])
regress_values = northern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_only["latitude_deg"],northern_only["humidity_%"],edgecolors="black",facecolors="blue")

plt.plot(northern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

plt.title("Northern Hemisphere City vs. Humidity (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/NLat_Humid_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10150988157650301

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_only["latitude_deg"], southern_only["humidity_%"])
regress_values = southern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_only["latitude_deg"],southern_only["humidity_%"],edgecolors="black",facecolors="yellow")

plt.plot(southern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")

plt.title("Southern Hemisphere City vs. Humidity (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/SLat_Humid_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.023570076956766554

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_only["latitude_deg"], northern_only["cloudiness_%"])
regress_values = northern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_only["latitude_deg"],northern_only["cloudiness_%"],edgecolors="black",facecolors="blue")

plt.plot(northern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

plt.title("Northern Hemisphere City vs. Cloudiness (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/NLat_Cloud_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02058364836705801

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_only["latitude_deg"], southern_only["cloudiness_%"])
regress_values = southern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_only["latitude_deg"],southern_only["cloudiness_%"],edgecolors="black",facecolors="yellow")

plt.plot(southern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(-55,45),fontsize=15,color="red")

plt.title("Southern Hemisphere City vs. Cloudiness (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/SLat_Cloud_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 3.042294160004933e-08

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_only["latitude_deg"], northern_only["winds speed_mph"])
regress_values = northern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_only["latitude_deg"],northern_only["winds speed_mph"],edgecolors="black",facecolors="blue")

plt.plot(northern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")

plt.title("Northern Hemisphere City vs. Winds Speed (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Winds speed_mph")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/NLat_Wind_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.12979733847474498

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_only["latitude_deg"], southern_only["winds speed_mph"])
regress_values = southern_only["latitude_deg"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_only["latitude_deg"],southern_only["winds speed_mph"],edgecolors="black",facecolors="yellow")

plt.plot(southern_only["latitude_deg"],regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")

plt.title("Latitude (Southern Hemisphere City ) vs. Winds Speed (11/03/2020)")
plt.xlabel("Latitude")
plt.ylabel("Winds Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Plots/SLat_Wind_Regres.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08652124865729166
